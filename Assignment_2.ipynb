# %% [markdown]
# # <b> <span style="color:white">Electricity Sector Data Streaming & Analysis</span></b>

# %% [markdown]
# # <b> <span style="color:white">GROUP 04</span></b>

# %% [markdown]
# | Name                   | SID       | Unikey   |
# | ---------------------- | --------- | -------- |
# | Putu Eka Udiyani Putri | 550067302 | pput0940 |
# | Rengga Firmandika      | 550126632 | rfir0117 |
# | Vincentius Ansel Suppa | 550206406 | vsup0468 |

# %% [markdown]
# ## <b> <span style="color:orange">0. Configuration and Import Required Libraries</span></b>

# %% [markdown]
# **Quick start:**
# 1. Project structure:
#
#    <pre>
#    Assignment2_Tut07_G04/
#    ├── Assignment_2.ipynb      # main notebook
#    └── requirements.txt        # list of required libraries to run the notebook
#    </pre>
#
#    Ensure your working directory is writable.
#
# 2. Create venv & install exact dependencies<br/>
#    `python -m venv .venv`<br/>
#    Windows: `.\.venv\Scripts\activate` | macOS/Linux: `source .venv/bin/activate`<br/>
#    `python -m pip install --upgrade pip`<br/>
#    `pip install -r requirements.txt`
#
# 3. Copy `.env.template` to `.env` file, replace `your_api_key` with your actual API key.
#
# 4. Run the full pipeline<br/>

# %% [markdown]
# Import all the required libraries first.

# %%
from dotenv import load_dotenv
from rapidfuzz import fuzz, process
from collections import Counter
from datetime import datetime, timedelta
from pathlib import Path

import os
import requests
import pandas as pd
import time
import json
import math
import glob
import paho.mqtt.client as mqtt
import sys
import duckdb
import importlib 
import re
import numpy as np

# %%
# Minimal DuckDB connection helpers
_DUCK = None

def _healthy(conn) -> bool:
    try:
        conn.execute("SELECT 1")
        return True
    except Exception:
        return False

def get_duck(db_path: str = "energy_dw.duckdb", read_only: bool = True):
    """Return a reusable DuckDB connection. Creates it if missing or broken."""
    global _DUCK
    if _DUCK is not None and _healthy(_DUCK):
        return _DUCK
    _DUCK = duckdb.connect(db_path, read_only=read_only)
    return _DUCK

def close_duck():
    """Close and reset the global connection."""
    global _DUCK
    if _DUCK is not None:
        try:
            _DUCK.close()
        except Exception:
            pass
        _DUCK = None

# %% [markdown]
# ## <b> <span style="color:orange">1. Data Retrieval</span></b>

# %% [markdown]
# In this project, we integrate facility data from Assignment 1 with the time series data from OpenElectricity. First, we will load the Assignment 1 facility data.
#
# We will do this with this workflow:
# 1. Get all operating facilities in NEM region from OpenElectricity.
# 2. Get all operating facilities in NEM region from Assignment 1 (NGER data).
# 3. Match the facilities from both sources and get all the required information for the next steps.
# 4. Get the per facility time series power and emissions data from OpenElectricity (using facility code we have acquired from previous steps).
# 5. Get the per region time series market price and demand.
# 6. Consolidate all retrieved data in one csv file.

# %% [markdown]
# First, we define some helper functions for OpenElectricity API calls.

# %%
# basic configs
API_KEY = os.getenv("OPENELECTRICITY_API_KEY")
API_KEY = API_KEY.strip().strip('"').strip("'")  
BASE_URL = "https://api.openelectricity.org.au/v4/"
HEADERS = {
        "Authorization": f"Bearer {API_KEY}",
        "Accept": "application/json",
    }
MARKET_PATH = "market/network"


# function to fetch data from facility endpoint
def fetch_data_from_API(endpoint: str, query_params: dict): 
    try:
        response = requests.get(f"{BASE_URL}{endpoint}", headers=HEADERS, params=query_params)
        
        print(f"Response status: {response.status_code}")
        print(f"Response url: {response.url}")
        
        if response.status_code == 200:
            return response.json()
        else:
            print(f"API Error {response.status_code}: {response.text}")
            print(f"Response headers: {dict(response.headers)}")

            try:
                error_json = response.json()
                print(f"Error details: {error_json}")
            except:
                print("Could not parse error response as JSON")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None

# function to fetch data from market endpoint
def fetch_market_data(network="NEM",
                      start_utc=None,
                      end_utc=None,
                      metrics=("price", "demand_energy"),
                      interval="5m",
                      primary_grouping="network_region"):
    """
    Flatten skema OpenElectricity (observed):
    data[list] -> item -> results[list] -> {
        name: 'price_NSW1' / 'demand_energy_NSW1',
        columns: {'region': 'NSW1'},
        data: [[timestamp, value], ...]
    }
    Output: timestamp, network_region, metric, value
    """
    endpoint = f"{MARKET_PATH}/{network}"

    params = []
    for m in metrics:
        params.append(("metrics", m))
    params += [
        ("interval", interval),
        ("date_start", start_utc),
        ("date_end", end_utc),
        ("primary_grouping", primary_grouping),
        ("with_clerk", "false"),
    ]
    params = [(k, v) for (k, v) in params if v is not None]

    payload = fetch_data_from_API(endpoint=endpoint, query_params=params)
    if payload is None:
        return pd.DataFrame()

    items = payload.get("data", [])
    rows = []

    for item in items:
        metric_name = item.get("metric")
        for res in item.get("results", []):
            region = None
            cols_meta = res.get("columns", {})
            if isinstance(cols_meta, dict):
                # contoh: {'region': 'NSW1'}
                region = cols_meta.get("region", region)

            for row in res.get("data", []):
                if not row:
                    continue
                ts = row[0]
                val = row[1] if len(row) > 1 else None
                rows.append({
                    "timestamp": ts,
                    "network_region": region,
                    "metric": metric_name,
                    "value": val
                })

    df = pd.DataFrame(rows)

    # Normalisation & sort
    if "timestamp" in df.columns:
        df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce", utc=True)

    df = df.sort_values([c for c in ["timestamp", "network_region"] if c in df.columns])
    return df.reset_index(drop=True)

# helper function to save dataset
def save_dataset(df: pd.DataFrame, out_csv_path: str):
	out_path = Path(out_csv_path)
	out_path.parent.mkdir(parents=True, exist_ok=True)
	df.to_csv(out_path, index=False)
	print(f"Saved: {out_path}")

# %% [markdown]
# ### <b> <span style="color:pink">1.1 Get All Facilities in NEM Region from OpenElectricity API Facility Endpoint</span></b>

# %% [markdown]
# To get all operating facilities in NEM region, we will use the facilities endpoint from Open Electricity. This is an important step because from this endpoint, we will get the facility code from all facilities, which will be used to get the time series data from the facility data endpoint.

# %%
# set endpoint and params
ENDPOINT = "facilities/"
PARAMS = {
    'network_id': 'NEM',
    'status_id': 'operating'
}

# fetch facilities data
facilities = fetch_data_from_API(endpoint=ENDPOINT, query_params=PARAMS)
facilities_df = pd.json_normalize(facilities['data'])
facilities_df.head()
# Out:
# Response status: 200
# Response url: https://api.openelectricity.org.au/v4/facilities/?network_id=NEM&status_id=operating
#        code                   name network_id network_region  \
# 0       ADP  Adelaide Desalination        NEM            SA1
# 1   ALDGASF                 Aldoga        NEM           QLD1
# 2  ANGASTON               Angaston        NEM            SA1
# 3     APPIN                  Appin        NEM           NSW1
# 4      ARWF                 Ararat        NEM           VIC1
#
#                                          description  \
# 0  <p>The Adelaide Desalination plant (ADP), form...
# 1  <p>The Aldoga Solar Farm will be approximately...
# 2  <p>Angaston Power Station is a diesel-powered ...
# 3  <p>In a world first, EDL developed the largest...
# 4  <p>Ararat Wind Farm is wind farm in western Vi...
#
#                                                units            updated_at  \
# 0  [{'code': 'ADPPV1', 'fueltech_id': 'solar_util...  2025-08-05T06:08:12Z
# 1  [{'code': 'ALDGASF1', 'fueltech_id': 'solar_ut...  2025-03-25T00:52:44Z
# 2  [{'code': 'ANGAST1', 'fueltech_id': 'distillat...  2025-09-07T01:53:13Z
# 3  [{'code': 'APPIN', 'fueltech_id': 'gas_wcmg', ...  2025-09-07T01:53:15Z
# 4  [{'code': 'ARWF1', 'fueltech_id': 'wind', 'sta...  2025-07-08T03:42:06Z
#
#              created_at  location.lat  location.lng
# 0  2023-10-18T04:34:30Z    -35.096948    138.484061
# 1  2025-01-31T04:19:33Z    -23.839544    151.084900
# 2  2023-10-18T04:34:32Z    -34.503948    139.024296
# 3  2023-10-18T04:34:32Z    -34.210868    150.792711
# 4  2023-10-18T04:34:32Z    -37.263393    143.082116

# %% [markdown]
# Some facilities have more than one units, so we need to make separate tables for easier analysis.

# %%
# function to separate the facilities and units rows
def build_tables(facilities: list[dict]):
    facility_rows: list[dict] = []
    unit_rows: list[dict] = []

    for f in facilities:
        f_code = f.get("code")
        facility_rows.append({
            "facility_code": f_code,
            "facility_name": f.get("name"),
            "network_id": f.get("network_id"),
            "network_region": f.get("network_region"),
            "lat": (f.get("location") or {}).get("lat"),
            "lng": (f.get("location") or {}).get("lng"),
            "created_at": f.get("created_at"),
            "updated_at": f.get("updated_at"),
        })

        for u in (f.get("units") or []):
                # unify field names we care about
                unit_rows.append({
                    "unit_code": u.get("code"),
                    "facility_code": f_code,
                    "fueltech_id": u.get("fueltech_id"),
                    "status_id": u.get("status_id"),
                    "dispatch_type": u.get("dispatch_type"),
                    "capacity_registered": u.get("capacity_registered"),
                    "capacity_maximum": u.get("capacity_maximum"),
                    "capacity_storage": u.get("capacity_storage"),
                    "data_first_seen": u.get("data_first_seen"),
                    "data_last_seen": u.get("data_last_seen"),
                    "unit_created_at": u.get("created_at"),
                    "unit_updated_at": u.get("updated_at"),
                })
    
    facilities_df = pd.DataFrame(facility_rows).drop_duplicates(subset=["facility_code"]).reset_index(drop=True)
    units_lookup_df = pd.DataFrame(unit_rows).drop_duplicates(subset=["unit_code"]).reset_index(drop=True)

    return facilities_df, units_lookup_df

# %%
facilities_df, units_facilities_df = build_tables(facilities['data'])

# save to csv
save_dataset(facilities_df, "DATA/EXTRACTED/electricity_facilities.csv")
save_dataset(units_facilities_df, "DATA/EXTRACTED/electricity_units_facilities.csv")
# Out:
# Saved: DATA\EXTRACTED\electricity_facilities.csv
# Saved: DATA\EXTRACTED\electricity_units_facilities.csv

# %% [markdown]
# ### <b> <span style="color:pink">1.2 Get All Facilities in NEM Region from NGER</span></b>

# %% [markdown]
# After getting all the operating facilities data in NEM region, we will start matching these data with the assignment 1 facility data we have just extracted earlier.

# %%
# cleanup just for once
try:
    con.close()
except Exception:
    pass

DB_PATH = "energy_dw.duckdb"
con = duckdb.connect(DB_PATH)

# %%
# Pull both sources (from DB and from API)
query = """
            SELECT DISTINCT
                f.facility_id,
                dfa.facility_name,
                dfu.fuel_type,
                dfu.fuel_category,
                dfu.is_renewable,
                dge.latitude,
                dge.longitude,
                dge.state_code AS region,
                dge.geo_resolution
            FROM fact_nger_facility f
            JOIN dim_facility dfa ON dfa.facility_id=f.facility_id
            JOIN dim_fuel dfu ON dfu.fuel_key=f.fuel_key
            JOIN dim_geo dge ON dge.geo_id=f.geo_id
            WHERE f.grid='NEM'
            GROUP BY 1,2,3,4,5,6,7,8,9
        """

facility_master = con.execute(query).df()
print("Facility master from DB:", facility_master.shape)
facility_master.head()
# Out:
# Facility master from DB: (446, 9)
#    facility_id                        facility_name            fuel_type  \
# 0          527          The Hayman Solar Farm Trust                Solar
# 1          524               GESS ProjectCo Pty Ltd              Battery
# 2          474     Oaky Creek II WCMG Power Station  Waste Coal Mine Gas
# 3          131    Lucas Heights 2 LFG Power Station         Landfill Gas
# 4          787  Rocky Point Sugar Mill Cogeneration              Bagasse
#
#   fuel_category  is_renewable   latitude   longitude region geo_resolution
# 0         SOLAR          True -22.164678  144.584490    QLD          state
# 1       STORAGE         False -36.598610  144.678005    VIC          state
# 2           GAS         False -22.164678  144.584490    QLD          state
# 3           BIO          True -31.875984  147.286949    NSW          state
# 4           BIO          True -22.164678  144.584490    QLD          state

# %% [markdown]
# ### <b> <span style="color:pink">1.3 Match Facilities from NGER (DB) and OpenElectrivity (API)</span></b>

# %% [markdown]
# The following cell sets up the matching framework that standardises and prepares both datasets (database and API) for subsequent matching attempts.
# It defines helper functions to clean names, align region codes, track progress, and prevent duplicate matches across attempts.
# This framework is executed once at the start and serves as the foundation for all following matching strategy cells.

# %%
# Matching Framework (API-based progress)

# Helpers
REGION_MAP = {"NSW":"NSW1","QLD":"QLD1","VIC":"VIC1","SA":"SA1","TAS":"TAS1"}
ALLOWED_NEM = {"NSW1","QLD1","VIC1","SA1","TAS1"}

def normalise_name(s: str) -> str:
    if not isinstance(s, str): 
        return ""
    s = s.lower()
    s = re.sub(r"\b(pty\s*ltd|limited|power\s*station|pp|plant|facility|unit|station|co|company|sf|wf)\b", " ", s)
    s = re.sub(r"[^a-z0-9]+", "", s)
    return s

PREVIEW_COLS = [
    "facility_code_api",     # API_facility_code
    "facility_name_api",     # API_facility_name
    "API_name",              # API_name (raw)
    "region_api",            # API_network_region
    "lat_api",
    "lng_api",
    "facility_id",
    "facility_name",         # DB_facility_name
    "fuel_type",             # DB_fuel_type
    "fuel_category",         # DB_fuel_category
    "is_renewable",          # DB_is_renewable
]

# Build API working frame
api_raw = facilities_df.copy()

api_work = api_raw.rename(columns={
    "facility_code": "facility_code_api",
    "facility_name": "facility_name_api",
    "network_region": "region_api",
    "lat": "lat_api",
    "lng": "lng_api",
}).copy()

# keep a raw name column for display (API_name)
if "facility_name_api" in api_work.columns:
    api_work["API_name"] = api_work["facility_name_api"]
elif "name" in api_raw.columns:
    api_work["API_name"] = api_raw["name"]
else:
    api_work["API_name"] = pd.NA

api_keep = ["facility_code_api","facility_name_api","API_name","region_api","lat_api","lng_api"]
api_work = api_work[[c for c in api_keep if c in api_work.columns]].drop_duplicates()

# normalised fields
api_work["facility_code_api"] = api_work["facility_code_api"].astype(str).str.upper().str.strip()
api_work["name_norm_api"]     = api_work["facility_name_api"].map(normalise_name) if "facility_name_api" in api_work.columns else ""
api_work["region_api"]        = api_work["region_api"].astype(str).str.upper().str.strip()

# Build DB working frame (filtered to NEM only)
db_work = facility_master.copy()

# standardise for joins
db_work["region_nem"]        = (
    db_work["region"].astype(str).str.upper().str.strip().map(REGION_MAP).fillna(db_work["region"])
)
db_work["name_norm_db"]      = db_work["facility_name"].map(normalise_name)

# filter DB to NEM universe
db_work = db_work.loc[db_work["region_nem"].isin(ALLOWED_NEM)].copy()

# tracking columns
for col in ["matched_api_code","matched_strategy"]:
    if col not in db_work.columns:
        db_work[col] = pd.NA

# ---------- Global registry to prevent reuse of API facility codes ----------
# Build from existing matches so rerunning framework keeps state
_existing_used = set(
    db_work.loc[db_work["matched_api_code"].notna(), "matched_api_code"]
          .astype(str)
          .tolist()
)

if "used_api_codes" in globals() and isinstance(used_api_codes, set):
    used_api_codes |= _existing_used
else:
    used_api_codes = set(_existing_used)

# ---------- Utilities ----------
def _progress(label: str):
    """Print API-based progress only."""
    total_api = len(api_work)
    used_api  = len(used_api_codes)
    remaining_api = total_api - used_api
    pct_api = 0.0 if total_api == 0 else used_api / total_api * 100.0
    print(f"[{label}] API: total={total_api}, matched={used_api}, remaining={remaining_api}, progress={pct_api:.2f}%")

def _preview(label: str, joined, n=10):
    for c in PREVIEW_COLS:
        if c not in joined.columns:
            joined[c] = pd.NA
    out = joined[PREVIEW_COLS].copy()
    print(f"\n[{label}] Preview of newly matched rows ({len(out)} rows; showing up to {n}):")
    display(out.head(n))
    return out

def _apply_matches(label: str, candidates, api_code_col="facility_code_api"):
    """
    Apply dedup-safe matches back to db_work and display one compact preview table.
    - processes only DB rows still unmatched,
    - drops NaN API codes,
    - refuses reusing API codes already applied,
    - reports API-only progress and duplicate diagnostics,
    - PREVIEW ONLY rows that were actually applied.
    """
    global db_work, api_work, used_api_codes

    # only DB rows not yet matched
    candidates = candidates.loc[db_work["matched_api_code"].isna()].copy()

    # drop NaN API codes early
    before_nan = len(candidates)
    candidates = candidates[candidates[api_code_col].notna()].copy()
    dropped_nan = before_nan - len(candidates)

    # avoid reusing API codes
    before_used = len(candidates)
    candidates = candidates[~candidates[api_code_col].isin(used_api_codes)].copy()
    dropped_used = before_used - len(candidates)

    if candidates.empty:
        print(f"[{label}] No new matches. (dropped_nan={dropped_nan}, dropped_used={dropped_used})")
        _progress(label)
        return pd.DataFrame(columns=PREVIEW_COLS)

    # apply matches and remember which DB indices actually got applied
    applied_idx = []
    for idx, row in candidates.iterrows():
        api_code = row[api_code_col]
        if pd.isna(api_code) or api_code in used_api_codes:
            continue
        db_work.at[idx, "matched_api_code"] = api_code
        db_work.at[idx, "matched_strategy"] = label
        used_api_codes.add(api_code)
        applied_idx.append(idx)

    if not applied_idx:
        print(f"[{label}] All candidates were skipped after guards. (dropped_nan={dropped_nan}, dropped_used={dropped_used})")
        _progress(label)
        return pd.DataFrame(columns=PREVIEW_COLS)

    # build preview ONLY for applied indices
    applied_slice = db_work.loc[applied_idx].merge(
        api_work, left_on="matched_api_code", right_on="facility_code_api", how="left"
    )

    _progress(label)
    dup_ids = db_work.loc[db_work["matched_api_code"].notna(), "matched_api_code"].duplicated(keep=False).sum()
    print(f"[{label}] duplicate API codes after guard: {dup_ids} | applied={len(applied_idx)} "
          f"| dropped_nan={dropped_nan} | dropped_used={dropped_used}")

    return _preview(label, applied_slice)

print("Matching framework ready (API-based progress).")
# Out:
# Matching framework ready (API-based progress).

# %%
# Attempt 1 — Exact name_norm + same region

assert all(k in globals() for k in ["db_work", "api_work", "_apply_matches"]), \
    "Run the Matching Framework cell first."

label = "Attempt 1: exact name_norm + region"

# Work only on DB rows not matched yet
left = db_work.loc[db_work["matched_api_code"].isna(), ["name_norm_db", "region_nem"]].copy()
left["key"] = left["name_norm_db"].fillna("") + "|" + left["region_nem"].fillna("")
left["db_idx"] = left.index  # keep original DB index

# Prepare API side with the same composite key and make keys unique
right = api_work.loc[:, ["name_norm_api", "region_api", "facility_code_api"]].copy()
right["key"] = right["name_norm_api"].fillna("") + "|" + right["region_api"].fillna("")
right = right.drop_duplicates(subset=["key"], keep="first")  # enforce 1:1 mapping per key

# Left-join using the composite key; keep original DB index
joined = left.merge(right[["key", "facility_code_api"]], on="key", how="left")
joined = joined.set_index("db_idx")

# Build candidates and apply matches
candidates = joined[["facility_code_api"]]

_ = _apply_matches(label, candidates)
# Out:
# [Attempt 1: exact name_norm + region] API: total=420, matched=22, remaining=398, progress=5.24%
# [Attempt 1: exact name_norm + region] duplicate API codes after guard: 0 | applied=22 | dropped_nan=422 | dropped_used=0
#
# [Attempt 1: exact name_norm + region] Preview of newly matched rows (22 rows; showing up to 10):
#   facility_code_api        facility_name_api                 API_name  \
# 0           KENNEDY      Kennedy Energy Park      Kennedy Energy Park
# 1               VBB    Victorian Big Battery    Victorian Big Battery
# 2          HORNSDPR  Hornsdale Power Reserve  Hornsdale Power Reserve
# 3              LRSF                Longreach                Longreach
# 4         CALLIDEC1                Callide C                Callide C
# 5            BARRON             Barron Gorge             Barron Gorge
# 6           WSTWYSF             West Wyalong             West Wyalong
# 7            CALL_B                Callide B                Callide B
# 8              OCPS               Oaky Creek               Oaky Creek
# 9           TAHMOOR                  Tahmoor                  Tahmoor
#
#   region_api    lat_api     lng_api  facility_id  \
# 0       QLD1 -20.872792  144.413034          688
# 1       VIC1 -38.038280  144.291003          698
# 2        SA1 -33.085519  138.521914          506
# 3       QLD1 -23.455048  144.227917          581
# 4       QLD1 -24.347222  150.608611           69
# 5       QLD1 -16.850770  145.647049          325
# 6       NSW1 -33.795635  147.314545          788
# 7       QLD1 -24.333169  150.626322           68
# 8       QLD1 -23.048717  148.484462          138
# 9       NSW1 -34.249117  150.577718          144
#
#                      facility_name            fuel_type fuel_category  \
# 0      Kennedy Energy Park Pty Ltd                 Wind          WIND
# 1    VICTORIAN BIG BATTERY PTY LTD              Battery       STORAGE
# 2  HORNSDALE POWER RESERVE PTY LTD              Battery       STORAGE
# 3                     Longreach SF                Solar         SOLAR
# 4          Callide C Power Station           Black Coal          COAL
# 5       Barron Gorge Power Station                Hydro         HYDRO
# 6                  West Wyalong SF                Solar         SOLAR
# 7          Callide B Power Station           Black Coal          COAL
# 8         Oaky Creek Power Station    Coal Seam Methane           GAS
# 9            Tahmoor Power Station  Waste Coal Mine Gas           GAS
#
#    is_renewable
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
# 5          True
# 6          True
# 7         False
# 8         False
# 9         False

# %%
# Attempt 2 — Fuzzy name within same region

assert all(k in globals() for k in ["db_work", "api_work", "_apply_matches"]), \
    "Run the Matching Framework cell first."


label = "Attempt 3: fuzzy name within region"
threshold = 90

# Work only on DB rows not matched yet
unmatched = db_work.loc[db_work["matched_api_code"].isna(), ["name_norm_db", "region_nem"]].copy()

rows = []
for region, chunk in unmatched.groupby("region_nem"):
    # API candidates within same region, with non-empty normalised names
    candidates_api = api_work.query("region_api == @region and name_norm_api != ''").copy()
    if candidates_api.empty:
        continue

    # Optionally exclude API codes already used to reduce collisions
    if "used_api_codes" in globals() and len(used_api_codes) > 0:
        candidates_api = candidates_api[~candidates_api["facility_code_api"].isin(used_api_codes)]

    if candidates_api.empty:
        continue

    names_api = candidates_api["name_norm_api"].tolist()
    idx_api   = candidates_api.index.tolist()

    for i, row in chunk.iterrows():
        q = row["name_norm_db"]
        if not q:
            continue
        best = process.extractOne(q, names_api, scorer=fuzz.token_set_ratio)
        if best and best[1] >= threshold:
            api_row = candidates_api.loc[idx_api[best[2]]]
            rows.append((i, api_row["facility_code_api"]))

# Build candidates DataFrame and apply matches
if rows:
    candidates = pd.DataFrame(rows, columns=["idx","facility_code_api"]).set_index("idx")
    _ = _apply_matches(label, candidates)
else:
    print(f"[{label}] No matches found.")
# Out:
# [Attempt 3: fuzzy name within region] API: total=420, matched=24, remaining=396, progress=5.71%
# [Attempt 3: fuzzy name within region] duplicate API codes after guard: 0 | applied=2 | dropped_nan=0 | dropped_used=0
#
# [Attempt 3: fuzzy name within region] Preview of newly matched rows (2 rows; showing up to 10):
#   facility_code_api facility_name_api          API_name region_api    lat_api  \
# 0             OAKY2      Oaky Creek 2      Oaky Creek 2       QLD1 -23.048717
# 1          OAKEY1SF  Oakey Solar Farm  Oakey Solar Farm       QLD1 -27.402454
#
#       lng_api  facility_id               facility_name            fuel_type  \
# 0  148.484462          443  Oaky Creek I Power Station  Waste Coal Mine Gas
# 1  151.642576          616          Oakey 2 Solar Farm                Solar
#
#   fuel_category  is_renewable
# 0           GAS         False
# 1         SOLAR          True

# %%
# Attempt 3: Subset-name (containment) match on name_norm, optional region gate

LABEL = "A3_subset_norm_unique"

# Unmatched DB
db_unm = db_work.loc[db_work["matched_api_code"].isna(), ["name_norm_db"]].copy()

# API keys
api_cols = ["facility_code_api", "name_norm_api"]
use_region = ("region_api" in api_work.columns) and ("region_nem" in db_work.columns)
if use_region:
    db_unm["region_nem"] = db_work.loc[db_unm.index, "region_nem"]
    api_cols.append("region_api")

api_k = api_work[api_cols].drop_duplicates().copy()

def _candidates_for(db_row):
    """Return candidate API rows (as DataFrame) for one DB row by subset-name rule."""
    s_db = db_row["name_norm_db"]
    if not isinstance(s_db, str) or not s_db:
        return api_k.iloc[0:0]

    # Region gate if available
    pool = api_k
    if use_region:
        pool = pool[pool["region_api"] == db_row["region_nem"]]

    # Containment both directions, require min length >= 6 to avoid trivial hits
    mask = (
        (pool["name_norm_api"].str.contains(s_db, na=False)) |
        (pool["name_norm_api"].apply(lambda s: isinstance(s, str) and s_db.find(s) != -1))
    ) & (pool["name_norm_api"].str.len().fillna(0).clip(upper=10**9).where(lambda L: L >= 6, False) |
         (pd.Series([len(s_db) >= 6]*len(pool), index=pool.index)))

    return pool[mask][["facility_code_api"]]

# Build matches: only accept unique
rows = []
for idx, r in db_unm.iterrows():
    cand = _candidates_for(r)
    if len(cand) == 1:
        rows.append((idx, cand["facility_code_api"].iloc[0]))

if rows:
    candidates = pd.DataFrame(rows, columns=["_idx", "facility_code_api"]).set_index("_idx")
    # ensure API code unique (one DB per API)
    vc = candidates["facility_code_api"].value_counts()
    candidates = candidates[candidates["facility_code_api"].isin(vc[vc == 1].index)]
    _apply_matches(LABEL, candidates[["facility_code_api"]])
else:
    _apply_matches(LABEL, pd.DataFrame(columns=["facility_code_api"]))
# Out:
# [A3_subset_norm_unique] API: total=420, matched=149, remaining=271, progress=35.48%
# [A3_subset_norm_unique] duplicate API codes after guard: 0 | applied=125 | dropped_nan=0 | dropped_used=4
#
# [A3_subset_norm_unique] Preview of newly matched rows (125 rows; showing up to 10):
#   facility_code_api facility_name_api         API_name region_api    lat_api  \
# 0            HAYMSF            Hayman           Hayman       QLD1 -20.487516
# 1           WINTSF1            Winton           Winton       VIC1 -36.499695
# 2           WAGGNSF       Wagga North      Wagga North       NSW1 -35.069081
# 3           CHALLWF   Challicum Hills  Challicum Hills       VIC1 -37.395466
# 4          CATHROCK   Cathedral Rocks  Cathedral Rocks        SA1 -34.848741
# 5              WPWF      Wattle Point     Wattle Point        SA1 -35.115410
# 6             KARSF           Karadoc          Karadoc       VIC1 -34.227904
# 7           BERYLSF             Beryl            Beryl       NSW1 -32.347501
# 8            RUGBYR         Rugby Run        Rugby Run       QLD1 -21.940469
# 9              BAPS        Banimboola       Banimboola       VIC1 -36.534524
#
#       lng_api  facility_id                 facility_name fuel_type  \
# 0  147.744778          527   The Hayman Solar Farm Trust     Solar
# 1  146.114554          708             Winton Solar Farm     Solar
# 2  147.438227          696  Wagga Wagga North Solar Farm     Solar
# 3  143.104590          205     Challicum Hills Wind Farm      Wind
# 4  135.592649          154     Cathedral Rocks Wind Farm      Wind
# 5  137.718672           35        Wattle Point Wind Farm      Wind
# 6  142.280330          570            KARADOC SOLAR FARM     Solar
# 7  149.460738          676              Beryl Solar Farm     Solar
# 8  147.880877          603    Adani Rugby Run Solar Farm     Solar
# 9  147.459788            4              Banimboola Hydro     Hydro
#
#   fuel_category  is_renewable
# 0         SOLAR          True
# 1         SOLAR          True
# 2         SOLAR          True
# 3          WIND          True
# 4          WIND          True
# 5          WIND          True
# 6         SOLAR          True
# 7         SOLAR          True
# 8         SOLAR          True
# 9         HYDRO          True

# %%
# Attempt 4: One rare-token overlap (>=1 uncommon word), optional region gate, 1:1, dedup-safe

LABEL = "A4_one_rare_token"

STOP = {
    "wind","solar","gas","bio","biomass","diesel","hydro","coal","battery",
    "farm","power","station","plant","unit","pty","ltd","limited","company",
    "energy","project","park","river","creek","hill","range","ps","pp","sf","wf","lfg"
}
RARE_MAX = 3   # a token is rare if it appears <= 3 times globally
MINLEN   = 4   # ignore very short tokens

def toks(s: str) -> set:
    if not isinstance(s, str) or not s:
        return set()
    return {t for t in re.findall(r"[a-z0-9]+", s.lower()) if len(t) >= MINLEN and t not in STOP}

# Unmatched DB slice (keep DB index)
db_unm = db_work.loc[db_work["matched_api_code"].isna(), ["facility_name"]].copy()
db_unm["tok_db"] = db_unm["facility_name"].map(toks)

# API tokens
api_k = api_work[["facility_code_api","API_name"]].drop_duplicates().copy()
api_k["tok_api"] = api_k["API_name"].map(toks)

# Global token frequencies to identify "rare" tokens
all_tokens = [t for s in db_unm["tok_db"] for t in s] + [t for s in api_k["tok_api"] for t in s]
freq = Counter(all_tokens)

def rare_anchor_token(token_set: set) -> str:
    rare = [t for t in token_set if freq.get(t, 0) <= RARE_MAX]
    if not rare:
        return ""
    rare.sort(key=lambda t: (freq[t], -len(t), t))  # rarest, then longer, then lexicographic
    return rare[0]

db_unm["anchor"] = db_unm["tok_db"].map(rare_anchor_token)
api_k = api_k.assign(anchor=api_k["tok_api"].map(rare_anchor_token))

# Optional region gate
use_region = ("region_api" in api_work.columns) and ("region_nem" in db_work.columns)
if use_region:
    db_unm["region_nem"] = db_work.loc[db_unm.index, "region_nem"]
    api_k = api_k.merge(
        api_work[["facility_code_api","region_api"]].drop_duplicates(),
        on="facility_code_api", how="left"
    )

# Drop rows without an anchor (no rare token found)
db_unm = db_unm[db_unm["anchor"] != ""].copy()
api_k  = api_k[api_k["anchor"]  != ""].copy()

# Blocked join on the rare anchor (and region if available), preserving DB index
if use_region:
    cand = db_unm.join(
        api_k.set_index(["anchor","region_api"])[["facility_code_api","tok_api"]],
        on=["anchor","region_nem"], how="left"
    )
else:
    cand = db_unm.join(
        api_k.set_index("anchor")[["facility_code_api","tok_api"]],
        on="anchor", how="left"
    )

# Keep only rows with an API candidate
cand = cand.dropna(subset=["facility_code_api"]).copy()

# Ensure both token columns are sets (avoid NaN -> float)
cand["tok_db"]  = cand["tok_db"].apply(lambda s: s if isinstance(s, set) else set())
cand["tok_api"] = cand["tok_api"].apply(lambda s: s if isinstance(s, set) else set())

if cand.empty:
    _ = _apply_matches(LABEL, pd.DataFrame(columns=["facility_code_api"]))
else:
    # Compute overlap size and jaccard for tie-break
    overlap = []
    jaccard = []
    for s_db, s_api in zip(cand["tok_db"], cand["tok_api"]):
        inter = len(s_db & s_api)
        uni   = len(s_db | s_api) if (s_db or s_api) else 1
        overlap.append(inter)
        jaccard.append(inter/uni)
    cand["overlap"] = overlap
    cand["jaccard"] = jaccard

    # Require at least 1 shared rare/informative token
    cand = cand[cand["overlap"] >= 1].copy()

    if cand.empty:
        _ = _apply_matches(LABEL, pd.DataFrame(columns=["facility_code_api"]))
    else:
        # Pick single best per DB row (by overlap then jaccard)
        cand["rank_key"] = list(zip(cand["overlap"], cand["jaccard"]))
        best_idx = cand.groupby(cand.index)["rank_key"].idxmax()
        best = cand.loc[best_idx].copy()

        # Enforce 1:1 on API side (keep the best globally per API code)
        best = best.sort_values(["overlap","jaccard"], ascending=[False, False])
        best = best.drop_duplicates(subset=["facility_code_api"], keep="first")

        _ = _apply_matches(LABEL, best[["facility_code_api"]])
# Out:
# [A4_one_rare_token] API: total=420, matched=206, remaining=214, progress=49.05%
# [A4_one_rare_token] duplicate API codes after guard: 0 | applied=57 | dropped_nan=0 | dropped_used=15
#
# [A4_one_rare_token] Preview of newly matched rows (57 rows; showing up to 10):
#   facility_code_api facility_name_api          API_name region_api    lat_api  \
# 0          LUCAS2S2   Lucas Heights 2   Lucas Heights 2       NSW1 -34.044088
# 1             DPNTB  Darlington Point  Darlington Point       NSW1 -34.646668
# 2             DPNTB  Darlington Point  Darlington Point       NSW1 -34.646668
# 3           LK_ECHO         Lake Echo         Lake Echo       TAS1 -42.253339
# 4              BHWF        Bald Hills        Bald Hills       VIC1 -38.758189
# 5            CHYTWF       Cherry Tree       Cherry Tree       VIC1 -37.101800
# 6           GLRWNSF    Glenrowan West    Glenrowan West       VIC1 -36.488083
# 7           MBAHNTH    Moranbah North    Moranbah North       QLD1 -21.978481
# 8          GRANGEAV     Grange Avenue     Grange Avenue       NSW1 -33.713011
# 9          BUTLERSG     Butlers Gorge     Butlers Gorge       TAS1 -42.267107
#
#       lng_api  facility_id                        facility_name  \
# 0  150.972475          131    Lucas Heights 2 LFG Power Station
# 1  146.034982          643  Darlington Point Solar Farm Pty Ltd
# 2  146.034982          643  Darlington Point Solar Farm Pty Ltd
# 3  146.620515          735      Hydro Power Station - Lake Echo
# 4  145.956062          445         Bald Hills Wind Farm Pty Ltd
# 5  145.265600          678        Cherry Tree Wind Farm Pty Ltd
# 6  146.146887          645            Glenrowan West Solar Farm
# 7  148.004809          135     Moranbah North CMM Power Station
# 8  150.833160          362      Grange Avenue LFG Power Station
# 9  146.262127          174    Butlers Gorge Hydro Power Station
#
#              fuel_type fuel_category  is_renewable
# 0         Landfill Gas           BIO          True
# 1                Solar         SOLAR          True
# 2                Solar         SOLAR          True
# 3                Hydro         HYDRO          True
# 4                 Wind          WIND          True
# 5                 Wind          WIND          True
# 6                Solar         SOLAR          True
# 7  Waste Coal Mine Gas           GAS         False
# 8         Landfill Gas           BIO          True
# 9                Hydro         HYDRO          True

# %%
# Attempt 5: Relaxed fuzzy names

LABEL = "A5_token_jaccard_070_blk_long"

# Rebuild the same candidates quickly (uses existing db_work/api_work)
db_unm = db_work.loc[db_work["matched_api_code"].isna(), ["facility_name","region_nem"]].copy()
api_k  = api_work[["facility_code_api","API_name","facility_name_api","region_api"]].drop_duplicates().copy()

# Token helpers
STOP = {"wind","solar","gas","bio","biomass","diesel","hydro","coal","battery","farm","power","station","plant","unit","pty","ltd","limited","company","energy","project","park","river","creek","hill","range","ps","pp","sf","wf","lfg","the","and"}
tok = lambda s: {t for t in re.findall(r"[a-z0-9]+", str(s).lower()) if len(t) >= 3 and t not in STOP}
longest = lambda ss: (max(ss, key=len) if ss else "")

db_unm["tok_db"] = db_unm["facility_name"].map(tok)
api_k["tok_api"] = api_k["API_name"].map(tok)
db_unm["anchor"] = db_unm["tok_db"].map(longest)
api_k["anchor"]  = api_k["tok_api"].map(longest)

db_unm = db_unm[db_unm["anchor"] != ""].copy()
api_k  = api_k[api_k["anchor"]  != ""].copy()

cand = db_unm.join(
    api_k.set_index(["region_api","anchor"])[["facility_code_api","API_name","facility_name_api","tok_api"]],
    on=["region_nem","anchor"], how="left"
).dropna(subset=["facility_code_api"]).copy()

if cand.empty:
    _ = _apply_matches(LABEL, pd.DataFrame(columns=["facility_code_api"]))
else:
    # Jaccard + overlap
    jacc, ov = [], []
    for s_db, s_api in zip(cand["tok_db"], cand["tok_api"]):
        inter = len(s_db & s_api)
        union = len(s_db | s_api) if (s_db or s_api) else 1
        ov.append(inter); jacc.append(inter/union)
    cand["overlap"] = ov; cand["jaccard"] = jacc

    cand = cand[(cand["overlap"] >= 2) & (cand["jaccard"] >= 0.70)].copy()
    if cand.empty:
        _ = _apply_matches(LABEL, pd.DataFrame(columns=["facility_code_api"]))
    else:
        # Best per DB row
        cand["rank_key"] = list(zip(cand["jaccard"], cand["overlap"]))
        best_idx = cand.groupby(cand.index)["rank_key"].idxmax()
        best = cand.loc[best_idx].copy()

        # 1) enforce unique API code
        best = best.sort_values(["jaccard","overlap"], ascending=[False, False])
        best = best.drop_duplicates(subset=["facility_code_api"], keep="first")

        # 2) enforce unique API *name* (this removes duplicate facility_name_api in preview)
        if "facility_name_api" in best.columns:
            best = best.drop_duplicates(subset=["facility_name_api"], keep="first")

        _ = _apply_matches(LABEL, best[["facility_code_api"]])
# Out:
# [A5_token_jaccard_070_blk_long] API: total=420, matched=210, remaining=210, progress=50.00%
# [A5_token_jaccard_070_blk_long] duplicate API codes after guard: 0 | applied=4 | dropped_nan=0 | dropped_used=6
#
# [A5_token_jaccard_070_blk_long] Preview of newly matched rows (4 rows; showing up to 10):
#   facility_code_api facility_name_api        API_name region_api    lat_api  \
# 0            MUWAWF       Murra Warra     Murra Warra       VIC1 -36.438821
# 1           SNOWSTH    Snowtown South  Snowtown South        SA1 -33.862624
# 2              CESF      Capital East    Capital East       NSW1 -35.180684
# 3             DDPS1     Darling Downs   Darling Downs       QLD1 -27.116851
#
#       lng_api  facility_id                     facility_name fuel_type  \
# 0  142.246003          763          Murra Warra II Wind Farm      Wind
# 1  138.130367          671  Snowtown South Wind Farm Pty Ltd      Wind
# 2  149.546482          216           Capital East Solar Farm     Solar
# 3  150.895391          606          Darling Downs Solar Farm      Wind
#
#   fuel_category  is_renewable
# 0          WIND          True
# 1          WIND          True
# 2         SOLAR          True
# 3          WIND          True

# %%
# Attempt 6: Relaxed fuzzy within same region (threshold/partial >= 85) + containment fallback,

LABEL = "A6_relaxed_fuzzy_region_85"

# Unmatched DB + required region cols
db_unm = db_work.loc[db_work["matched_api_code"].isna(), ["name_norm_db", "region_nem"]].copy()
api_k  = api_work[["facility_code_api", "name_norm_api", "facility_name_api", "region_api"]].drop_duplicates().copy()

if db_unm.empty or api_k.empty or ("region_nem" not in db_unm.columns) or ("region_api" not in api_k.columns):
    _ = _apply_matches(LABEL, pd.DataFrame(columns=["facility_code_api"]))
else:
    # light blocking by 4-char prefix to cut pairings
    db_unm["blk4"] = db_unm["name_norm_db"].astype(str).str[:4]
    api_k["blk4"]  = api_k["name_norm_api"].astype(str).str[:4]

    cand = db_unm.join(
        api_k.set_index(["region_api","blk4"])[["facility_code_api","name_norm_api","facility_name_api"]],
        on=["region_nem","blk4"], how="left"
    ).dropna(subset=["facility_code_api"]).copy()

    if cand.empty:
        _ = _apply_matches(LABEL, pd.DataFrame(columns=["facility_code_api"]))
    else:
        # elementwise arrays (ensure pure strings)
        dn = cand["name_norm_db"].astype(str).tolist()
        an = cand["name_norm_api"].astype(str).tolist()

        # relaxed fuzzy: max(token_set_ratio, partial_ratio)
        base = np.array([max(fuzz.token_set_ratio(d, a), fuzz.partial_ratio(d, a)) for d, a in zip(dn, an)], dtype=float)

        # containment fallback computed elementwise (no np.char)
        contain = np.array([(a.find(d) != -1) or (d.find(a) != -1) for d, a in zip(dn, an)], dtype=bool)
        min_len = np.array([min(len(d), len(a)) for d, a in zip(dn, an)], dtype=int)

        score = np.where((base < 85) & contain & (min_len >= 5), 85.0, base)
        cand["score"] = score

        # pick single best per DB row
        best = cand.loc[cand.groupby(cand.index)["score"].idxmax()].copy()
        best = best[best["score"] >= 85].copy()

        if best.empty:
            _ = _apply_matches(LABEL, pd.DataFrame(columns=["facility_code_api"]))
        else:
            # enforce uniqueness on API code then API name
            best = best.sort_values(["score"], ascending=False).drop_duplicates(subset=["facility_code_api"], keep="first")
            if "facility_name_api" in best.columns:
                best = best.drop_duplicates(subset=["facility_name_api"], keep="first")

            _ = _apply_matches(LABEL, best[["facility_code_api"]])
# Out:
# [A6_relaxed_fuzzy_region_85] API: total=420, matched=239, remaining=181, progress=56.90%
# [A6_relaxed_fuzzy_region_85] duplicate API codes after guard: 0 | applied=29 | dropped_nan=0 | dropped_used=44
#
# [A6_relaxed_fuzzy_region_85] Preview of newly matched rows (29 rows; showing up to 10):
#   facility_code_api facility_name_api       API_name region_api    lat_api  \
# 0          SHOALHAV        Shoalhaven     Shoalhaven       NSW1 -34.733085
# 1          WOOLNTH1         Woolnorth      Woolnorth       TAS1 -40.736375
# 2            MANSLR          Manildra       Manildra       NSW1 -33.172831
# 3           EMERASF           Emerald        Emerald       QLD1 -23.508790
# 4           LIMOSF2       Limondale 2    Limondale 2       NSW1 -34.775502
# 5          NUMURKSF          Numurkah       Numurkah       VIC1 -36.159275
# 6          SNOWTOWN          Snowtown       Snowtown        SA1 -33.691598
# 7            AGLHAL           Hallett        Hallett        SA1 -33.349310
# 8            EILDON            Eildon         Eildon       VIC1 -37.221262
# 9         LKBONNY_2     Lake Bonney 2  Lake Bonney 2        SA1 -37.760504
#
#       lng_api  facility_id                            facility_name  \
# 0  150.466700           31           Shoalhaven Landfill Generation
# 1  144.694821          592  Woolnorth Bluff Point Wind Farm Pty Ltd
# 2  148.718240          677                      Manildra Solar Farm
# 3  148.128017          577                       Emerald Solar Park
# 4  143.508046          667                     Limondale Solar Farm
# 5  145.473891          844           Numurkah Project No. 2 Pty Ltd
# 6  138.166022          317               SNOWTOWN WIND FARM STAGE 2
# 7  138.752633           15              Hallett (Stage 1) Wind Farm
# 8  145.920966           12                             Eildon Hydro
# 9  140.405541          651                 Lake Bonney BESS Pty Ltd
#
#       fuel_type fuel_category  is_renewable
# 0  Landfill Gas           BIO          True
# 1          Wind          WIND          True
# 2         Solar         SOLAR          True
# 3         Solar         SOLAR          True
# 4         Solar         SOLAR          True
# 5         Solar         SOLAR          True
# 6          Wind          WIND          True
# 7          Wind          WIND          True
# 8         Hydro         HYDRO          True
# 9       Battery       STORAGE         False

# %%
# State sync (static results)
used_api_codes = set(
    db_work.loc[db_work["matched_api_code"].notna(), "matched_api_code"]
          .astype(str)
          .tolist()
)

# %%
# Attempt 7: two-token overlap + region

assert all(k in globals() for k in ["db_work", "api_work", "_apply_matches"]), \
    "Run the Matching Framework cell first."

label = "Attempt 7: two-token overlap + region)"

# deterministic behaviour across runs
np.random.seed(8)

# Lightweight tokenizer (same across attempts)
_STOP = {
    "power","station","plant","facility","unit","units","energy","generator","gen",
    "pty","ltd","company","co","project","site","phase","block","stage"
}
_TOKEN = re.compile(r"[a-z0-9]+")
def _tok(s):
    if not isinstance(s, str): 
        return set()
    toks = _TOKEN.findall(s.lower())
    return {t for t in toks if t not in _STOP and (t.isdigit() or len(t) > 1)}

# DB side: only unmatched rows
left = db_work.loc[db_work["matched_api_code"].isna(), ["facility_name","region_nem"]].copy()
left["__tok"] = left["facility_name"].map(_tok)
left["__reg"] = left["region_nem"].astype(str)
left = left[left["__tok"].map(bool)]
left = left.reset_index().rename(columns={"index":"db_idx"})
left_ex = left[["db_idx","__reg"]].join(left["__tok"].explode().rename("token"))

# API side
right = api_work.loc[:, ["API_name","region_api","facility_code_api"]].copy()
right["__tok"] = right["API_name"].map(_tok)
right["__reg"] = right["region_api"].astype(str)
right = right[right["__tok"].map(bool)]
right_ex = right[["facility_code_api","__reg"]].join(right["__tok"].explode().rename("token"))

# Candidate pairs via token + same region
cand = left_ex.merge(right_ex, on=["token","__reg"], how="inner")

# Token rarity weighting for tie-breaks
tok_freq = Counter(right_ex["token"].tolist())
cand["w"] = cand["token"].map(lambda t: 1.0 / (1 + tok_freq.get(t, 0)))

# Aggregate per (DB row, API facility)
agg = (
    cand.groupby(["db_idx","facility_code_api"], as_index=False)
         .agg(overlap=("token","nunique"), w_overlap=("w","sum"))
)

# Keep overlap ≥ 2
agg = agg[agg["overlap"] >= 2].copy()

# Add deterministic tie-breakers
api_len = (
    right.drop_duplicates(subset=["facility_code_api"])
         .set_index("facility_code_api")["__tok"]
         .map(len)
         .to_dict()
)
db_len = left.set_index("db_idx")["__tok"].map(len).to_dict()

agg["db_len"]  = agg["db_idx"].map(db_len)
agg["api_len"] = agg["facility_code_api"].map(api_len).fillna(0).astype(int)
agg["len_gap"] = (agg["db_len"] - agg["api_len"]).abs()

# Deterministic sort: prefer higher overlap, then w_overlap, smaller len_gap, alphabetical API code
agg = agg.sort_values(
    ["overlap", "w_overlap", "len_gap", "facility_code_api"],
    ascending=[False, False, True, True],
    kind="mergesort"
)

# Drop duplicates deterministically
best = agg.drop_duplicates(subset=["db_idx"], keep="first").set_index("db_idx")

# Apply matches (framework ensures dedup + progress)
candidates = best[["facility_code_api"]]
_ = _apply_matches(label, candidates)
# Out:
# [Attempt 7: two-token overlap + region)] API: total=420, matched=232, remaining=188, progress=55.24%
# [Attempt 7: two-token overlap + region)] duplicate API codes after guard: 0 | applied=2 | dropped_nan=0 | dropped_used=25
#
# [Attempt 7: two-token overlap + region)] Preview of newly matched rows (2 rows; showing up to 10):
#   facility_code_api    facility_name_api             API_name region_api  \
# 0              RPCG    Rocky Point Cogen    Rocky Point Cogen       QLD1
# 1               BHB  Broken Hill Battery  Broken Hill Battery       NSW1
#
#      lat_api     lng_api  facility_id  \
# 0 -27.733564  153.326464          787
# 1 -31.986300  141.420400          492
#
#                                        facility_name fuel_type fuel_category  \
# 0                Rocky Point Sugar Mill Cogeneration   Bagasse           BIO
# 1  Essential Energy Generation Facility - Broken ...    Diesel        LIQUID
#
#    is_renewable
# 0          True
# 1         False

# %%
# Attempt 8: first-word match + region

np.random.seed(9)

assert all(k in globals() for k in ["db_work", "api_work", "_apply_matches"]), \
    "Run the Matching Framework cell first."

label = "Attempt 8: first-word match + region"

def _first_word(s):
    if not isinstance(s, str):
        return ""
    s = s.lower().strip()
    s = re.sub(r"[^a-z0-9\s]+", " ", s)
    parts = s.split()
    return parts[0] if parts else ""

# DB side (only unmatched)
left = db_work.loc[db_work["matched_api_code"].isna(), ["facility_name", "region_nem"]].copy()
left["first_word"] = left["facility_name"].map(_first_word)
left["region_nem"] = left["region_nem"].astype(str).str.strip().str.upper()
left = left.reset_index().rename(columns={"index": "db_idx"})

# API side
right = api_work.loc[:, ["API_name", "region_api", "facility_code_api"]].copy()
right["first_word"] = right["API_name"].map(_first_word)
right["region_api"] = right["region_api"].astype(str).str.strip().str.upper()

# Make (first_word, region) unique deterministically:
# sort stable, then keep the first facility_code_api per pair
right_unique = (
    right.sort_values(
        ["first_word", "region_api", "facility_code_api"],
        ascending=[True, True, True],
        kind="mergesort"
    )
    .drop_duplicates(subset=["first_word", "region_api"], keep="first")
)

# Deterministic merge: now right side is unique per key -> m:1 is valid
joined = (
    left.merge(
        right_unique[["first_word", "region_api", "facility_code_api"]],
        left_on=["first_word", "region_nem"],
        right_on=["first_word", "region_api"],
        how="left",
        sort=False,
        validate="m:1"
    )
    .sort_values(["db_idx"], kind="mergesort")
    .set_index("db_idx")
)

# Candidates aligned to db_work index
candidates = joined[["facility_code_api"]]

# Apply (framework handles dedup + progress/preview)
_ = _apply_matches(label, candidates)
# Out:
# [Attempt 8: first-word match + region] API: total=420, matched=234, remaining=186, progress=55.71%
# [Attempt 8: first-word match + region] duplicate API codes after guard: 0 | applied=2 | dropped_nan=150 | dropped_used=59
#
# [Attempt 8: first-word match + region] Preview of newly matched rows (2 rows; showing up to 10):
#   facility_code_api    facility_name_api             API_name region_api  \
# 0           SNOWNTH       Snowtown North       Snowtown North        SA1
# 1             SHOAL  Shoalhaven Starches  Shoalhaven Starches       NSW1
#
#      lat_api     lng_api  facility_id       facility_name fuel_type  \
# 0 -33.756479  138.143043          316  Snowtown Wind Farm      Wind
# 1 -34.854700  150.613800          279   Shoalhaven Scheme     Hydro
#
#   fuel_category  is_renewable
# 0          WIND          True
# 1         HYDRO          True

# %%
# Use API frame from the framework
api_all = api_work.copy()
api_all["facility_code_api"] = api_all["facility_code_api"].astype(str).str.upper().str.strip()

# Prepare DB slice
db_cols_to_attach = [
    "matched_api_code",
    "facility_name",
    "facility_id",
    "fuel_type",
    "fuel_category",
    "is_renewable",
    "region_nem",
    "matched_strategy",
]
db_slice = db_work.loc[:, db_cols_to_attach].copy()
db_slice["matched_api_code"] = db_slice["matched_api_code"].astype(str).str.upper().str.strip()

# Deduplicate DB keys
dup_cnt = db_slice["matched_api_code"].duplicated(keep=False).sum()
if dup_cnt > 0:
    db_slice = db_slice.drop_duplicates(subset=["matched_api_code"], keep="first")

# Left-join: All API rows preserved, DB columns attached where matched
final_df = api_all.merge(
    db_slice,
    left_on="facility_code_api",
    right_on="matched_api_code",
    how="left",
    validate="m:1"
)

# Convenience flag & ordering
final_df["matched_flag"] = final_df["matched_api_code"].notna()
final_df = final_df.sort_values(["matched_flag", "facility_code_api"], ascending=[False, True])

# Save to CSV
out_dir = "DATA/OUTPUT"
os.makedirs(out_dir, exist_ok=True)
out_path = os.path.join(out_dir, "api_db_join_attempt.csv")
final_df.to_csv(out_path, index=False)

# Summary (API-based)
total_api = len(api_all)
matched_api = int(final_df["matched_flag"].sum())
progress_api = 0.0 if total_api == 0 else matched_api / total_api * 100.0

print(f"CSV saved → {out_path}")
print(f"API rows (expected 419): {total_api}")
print(f"Matched (API-based):    {matched_api} ({progress_api:.2f}%)")

display(final_df.head(10))
# Out:
# CSV saved → DATA/OUTPUT\api_db_join_attempt.csv
# API rows (expected 419): 420
# Matched (API-based):    234 (55.71%)
#     facility_code_api facility_name_api      API_name region_api    lat_api  \
# 148            AGLHAL           Hallett       Hallett        SA1 -33.349310
# 185           AGLSITA       Kemps Creek   Kemps Creek       NSW1 -33.874591
# 3               APPIN             Appin         Appin       NSW1 -34.210868
# 5               AVLSF           Avonlie       Avonlie       NSW1 -34.919115
# 7              BAKING      Baking Board  Baking Board       QLD1 -26.721166
# 9             BALBESS          Ballarat      Ballarat       VIC1 -37.567452
# 10            BANGOWF             Bango         Bango       NSW1 -34.767208
# 12             BANNSP         Bannerton     Bannerton       VIC1 -34.672630
# 11               BAPS        Banimboola    Banimboola       VIC1 -36.534524
# 13           BARCALDN        Barcaldine    Barcaldine       QLD1 -23.552171
#
#         lng_api name_norm_api matched_api_code  \
# 148  138.752633       hallett           AGLHAL
# 185  150.761858    kempscreek          AGLSITA
# 3    150.792711         appin            APPIN
# 5    146.609540       avonlie            AVLSF
# 7    150.554170   bakingboard           BAKING
# 9    143.852741      ballarat          BALBESS
# 10   148.921499         bango          BANGOWF
# 12   142.750362     bannerton           BANNSP
# 11   147.459788    banimboola             BAPS
# 13   145.314851    barcaldine         BARCALDN
#
#                          facility_name  facility_id            fuel_type  \
# 148        Hallett (Stage 1) Wind Farm         15.0                 Wind
# 185               Kemps Creek Landfill        597.0         Landfill Gas
# 3              Appin CSM Power Station        101.0  Waste Coal Mine Gas
# 5                   Avonlie Solar Farm        797.0                Solar
# 7              Baking Board Solar Farm        563.0                Solar
# 9                  Ballarat Solar Park        259.0                Solar
# 10                     Bango Wind Farm        648.0                 Wind
# 12                Bannerton Solar Farm        621.0                Solar
# 11                    Banimboola Hydro          4.0                Hydro
# 13   Barcaldine Power Station Facility        447.0                  Gas
#
#     fuel_category is_renewable region_nem  \
# 148          WIND         True        SA1
# 185           BIO         True       NSW1
# 3             GAS        False       NSW1
# 5           SOLAR         True       NSW1
# 7           SOLAR         True       QLD1
# 9           SOLAR         True       VIC1
# 10           WIND         True       NSW1
# 12          SOLAR         True       VIC1
# 11          HYDRO         True       VIC1
# 13            GAS        False       QLD1
#
#                         matched_strategy  matched_flag
# 148           A6_relaxed_fuzzy_region_85          True
# 185                    A4_one_rare_token          True
# 3                      A4_one_rare_token          True
# 5                  A3_subset_norm_unique          True
# 7                  A3_subset_norm_unique          True
# 9                      A4_one_rare_token          True
# 10                 A3_subset_norm_unique          True
# 12                 A3_subset_norm_unique          True
# 11                 A3_subset_norm_unique          True
# 13   Attempt 1: exact name_norm + region          True

# %%
final_df = final_df.rename(columns={
    'facility_code_api': 'facility_code',
    'region_api': 'network_region',
    'lat_api': 'lat',
    'lng_api': 'lng'
})

final_df['facility_name'] = final_df.apply(
    lambda row: row['facility_name'] if row['matched_flag'] else row['facility_name_api'],
    axis=1
)

final_df = final_df[['facility_code', 'facility_name', 'network_region', 'lat', 'lng', 'fuel_type', 'matched_flag']]
final_df
# Out:
#     facility_code                facility_name network_region        lat  \
# 148        AGLHAL  Hallett (Stage 1) Wind Farm            SA1 -33.349310
# 185       AGLSITA         Kemps Creek Landfill           NSW1 -33.874591
# 3           APPIN      Appin CSM Power Station           NSW1 -34.210868
# 5           AVLSF           Avonlie Solar Farm           NSW1 -34.919115
# 7          BAKING      Baking Board Solar Farm           QLD1 -26.721166
# ..            ...                          ...            ...        ...
# 350        YABULU                   Townsville           QLD1 -19.200374
# 411      YALLOURN                   Yallourn W           VIC1 -38.177596
# 416        YARWUN                       Yarwun           QLD1 -23.830200
# 418         YAWWF                       Yawong           VIC1 -36.471022
# 419      YENDONWF                       Yendon           VIC1 -37.630952
#
#             lng            fuel_type  matched_flag
# 148  138.752633                 Wind          True
# 185  150.761858         Landfill Gas          True
# 3    150.792711  Waste Coal Mine Gas          True
# 5    146.609540                Solar          True
# 7    150.554170                Solar          True
# ..          ...                  ...           ...
# 350  146.618265                  NaN         False
# 411  146.347508                  NaN         False
# 416  151.149692                  NaN         False
# 418  143.361722                  NaN         False
# 419  144.022463                  NaN         False
#
# [420 rows x 7 columns]

# %% [markdown]
# For the non-matched rows, we will keep them but fill the missing columns (fuel_type) with OpenElectricity data.

# %%
units_df = pd.read_csv("DATA/EXTRACTED/electricity_units_facilities.csv")
facilities_df = pd.read_csv("DATA/EXTRACTED/electricity_facilities_matched.csv")

units_df['capacity_registered'] = pd.to_numeric(units_df['capacity_registered'], errors='coerce')

units_max= (units_df
             .sort_values('capacity_registered', ascending=False)
             .groupby('facility_code')
             .first()
             .reset_index())

fueltech_to_fuel_type = {
    'battery_discharging': 'Battery',
    'battery_charging': 'Battery',
    'battery': 'Battery',
    'wind': 'Wind',
    'solar_utility': 'Solar',
    'gas_ocgt': 'Gas',
    'bioenergy_biogas': 'Bioenergy',
    'distillate': 'Distillate',
    'gas_wcmg': 'Gas',
    'hydro': 'Hydro',
    'gas_ccgt': 'Gas',
    'gas_recip': 'Gas',
    'coal_black': 'Black Coal',
    'bioenergy_biomass': 'Bioenergy',
    'coal_brown': 'BrownCoal',
    'gas_steam': 'Gas',
    'pumps': 'Pumps',
}

units_max['fuel_type_mapped'] = units_max['fueltech_id'].map(fueltech_to_fuel_type)

facilities_df = facilities_df.merge(
    units_max[['facility_code', 'fuel_type_mapped']], 
    on='facility_code', 
    how='left'
)

facilities_df['fuel_type'] = facilities_df['fuel_type'].fillna(facilities_df['fuel_type_mapped'])
facilities_df = facilities_df.drop(columns=['fuel_type_mapped'])

# %%
facilities_df
# Out:
#     facility_code                facility_name network_region        lat  \
# 0     0TARONGBESS        Tarong Power Stations           QLD1 -26.780051
# 1          AGLHAL  Hallett (Stage 2) Wind Farm            SA1 -33.349310
# 2         AGLSITA         Kemps Creek Landfill           NSW1 -33.874591
# 3           APPIN      Appin CSM Power Station           NSW1 -34.210868
# 4           AVLSF           Avonlie Solar Farm           NSW1 -34.919115
# ..            ...                          ...            ...        ...
# 414        YABULU                   Townsville           QLD1 -19.200374
# 415      YALLOURN                   Yallourn W           VIC1 -38.177596
# 416        YARWUN                       Yarwun           QLD1 -23.830200
# 417         YAWWF                       Yawong           VIC1 -36.471022
# 418      YENDONWF                       Yendon           VIC1 -37.630952
#
#             lng          fuel_type  matched_flag
# 0    151.912068         Black Coal          True
# 1    138.752633               Wind          True
# 2    150.761858       Landfill Gas          True
# 3    150.792711  Coal Seam Methane          True
# 4    146.609540              Solar          True
# ..          ...                ...           ...
# 414  146.618265                Gas         False
# 415  146.347508          BrownCoal         False
# 416  151.149692                Gas         False
# 417  143.361722               Wind         False
# 418  144.022463               Wind         False
#
# [419 rows x 7 columns]

# %%
con.close()
con = duckdb.connect(DB_PATH)

con.execute("DROP TABLE IF EXISTS facility_opennem_mapping")

con.execute("""
    CREATE TABLE IF NOT EXISTS facility_opennem_mapping (
        facility_code VARCHAR,
        facility_name VARCHAR,
        network_region VARCHAR,
        lat DOUBLE,
        lng DOUBLE,
        fuel_type VARCHAR,
        matched_flag BOOLEAN
    )
""")

for _, row in facilities_df.iterrows():
    con.execute("""
        INSERT INTO facility_opennem_mapping 
        (facility_code, facility_name, network_region, 
         lat, lng, fuel_type, matched_flag)
        VALUES (?, ?, ?, ?, ?, ?, ?)
    """, [
        row['facility_code'],
        row['facility_name'],
        row['network_region'],
        row['lat'],
        row['lng'],
        row['fuel_type'],
        row['matched_flag']
    ])

con.commit()

con.execute("""
    CREATE INDEX IF NOT EXISTS idx_facility_code 
    ON facility_opennem_mapping(facility_code)
""")

con.commit()
con.close()

# %% [markdown]
# Save the cleaned dataset into a csv file.

# %% [markdown]
# ### <b> <span style="color:pink">1.4 Get All Power Generated and CO2 Emissions per Facility</span></b>

# %% [markdown]
# Facility data will return total data instead of facility specific data if we do not specify the facility code in tha API call. Hence, we need to pass the facility code we get from previous API call to this endpoint.

# %%
# get all facility code
FACILITY_LIST = facilities_df["facility_code"].tolist()
print(f"Total facilities: {len(FACILITY_LIST)}")
# Out:
# Total facilities: 419

# %% [markdown]
# However, since the parameter only accept 30 max characters and we have more than 500 facilities, passing all facility code at once will result in error. To get around that, we will use the batching strategy.

# %%
OUT_DIR = "./DATA/EXTRACTED"
os.makedirs(OUT_DIR, exist_ok=True)
ENDPOINT = "data/facilities/NEM"
batch_size = 5

# function chunk the facility code list into batches
def chunk_list(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i+n], i, min(i+n, len(lst))  

# batch retrieval
def batch_retrieval(batch_size:int):
    for batch, start, end in chunk_list(FACILITY_LIST, batch_size):
        batch_id = math.ceil(end/batch_size)
        cache_path = os.path.join(OUT_DIR, f"batch_{start+1:04d}_{end:04d}.json")

        if os.path.exists(cache_path):
            print(f"Batch {batch_id}: {start+1}-{end} already cached.")
            continue

        print(f"Fetching batch {batch_id}: facilities {start+1}–{end} ({batch})")

        # params
        params = {
            'network_code': 'NEM',
            'metrics': {'power', 'emissions'},
            'interval': '5m',
            "date_start": "2025-10-01",
            "date_end": "2025-10-08",
            "facility_code": {f for f in batch},
        }

        try:
            r = requests.get(f"{BASE_URL}{ENDPOINT}", headers=HEADERS, params=params, timeout=90)
            if r.status_code == 200:
                payload = r.json()
                with open(cache_path, "w") as f:
                    json.dump(payload, f, indent=2)
                print(f"Saved {cache_path}")
            else:
                print(f"HTTP {r.status_code}: {r.text[:150]}")
        except Exception as e:
            print(f"Batch {batch_id}: {e}")

        time.sleep(0.3)

# function to flatten the payload
def flatten(payload):
    rows = []
    for block in payload.get("data", []):
        metric   = block.get("metric")
        unit     = block.get("unit")
        interval = block.get("interval")
        for res in block.get("results", []):
            unit_code = (res.get("columns") or {}).get("unit_code")
            for ts, val in res.get("data", []):
                rows.append({"timestamp": ts, "unit_code": unit_code,
                            "metric": metric, "interval": interval, "unit": unit, "value": val})
    return rows

# %%
# Retrieve all facility data in batch of 5 per API call
batch_retrieval(5)
# Out:
# Batch 1: 1-5 already cached.
# Batch 2: 6-10 already cached.
# Batch 3: 11-15 already cached.
# Batch 4: 16-20 already cached.
# Batch 5: 21-25 already cached.
# Batch 6: 26-30 already cached.
# Batch 7: 31-35 already cached.
# Batch 8: 36-40 already cached.
# Batch 9: 41-45 already cached.
# Batch 10: 46-50 already cached.
# Batch 11: 51-55 already cached.
# Batch 12: 56-60 already cached.
# Batch 13: 61-65 already cached.
# Batch 14: 66-70 already cached.
# Batch 15: 71-75 already cached.
# Batch 16: 76-80 already cached.
# Batch 17: 81-85 already cached.
# Batch 18: 86-90 already cached.
# Batch 19: 91-95 already cached.
# Batch 20: 96-100 already cached.
# Batch 21: 101-105 already cached.
# Batch 22: 106-110 already cached.
# Batch 23: 111-115 already cached.
# Batch 24: 116-120 already cached.
# Batch 25: 121-125 already cached.
# Batch 26: 126-130 already cached.
# Batch 27: 131-135 already cached.
# Batch 28: 136-140 already cached.
# Batch 29: 141-145 already cached.
# Batch 30: 146-150 already cached.
# Batch 31: 151-155 already cached.
# Batch 32: 156-160 already cached.
# Batch 33: 161-165 already cached.
# Batch 34: 166-170 already cached.
# Batch 35: 171-175 already cached.
# Batch 36: 176-180 already cached.
# Batch 37: 181-185 already cached.
# Batch 38: 186-190 already cached.
# Batch 39: 191-195 already cached.
# Batch 40: 196-200 already cached.
# Batch 41: 201-205 already cached.
# Batch 42: 206-210 already cached.
# Batch 43: 211-215 already cached.
# Batch 44: 216-220 already cached.
# Batch 45: 221-225 already cached.
# Batch 46: 226-230 already cached.
# Batch 47: 231-235 already cached.
# Batch 48: 236-240 already cached.
# Batch 49: 241-245 already cached.
# Batch 50: 246-250 already cached.
# Batch 51: 251-255 already cached.
# Batch 52: 256-260 already cached.
# Batch 53: 261-265 already cached.
# Batch 54: 266-270 already cached.
# Batch 55: 271-275 already cached.
# Batch 56: 276-280 already cached.
# Batch 57: 281-285 already cached.
# Batch 58: 286-290 already cached.
# Batch 59: 291-295 already cached.
# Batch 60: 296-300 already cached.
# Batch 61: 301-305 already cached.
# Batch 62: 306-310 already cached.
# Batch 63: 311-315 already cached.
# Batch 64: 316-320 already cached.
# Batch 65: 321-325 already cached.
# Batch 66: 326-330 already cached.
# Batch 67: 331-335 already cached.
# Batch 68: 336-340 already cached.
# Batch 69: 341-345 already cached.
# Batch 70: 346-350 already cached.
# Batch 71: 351-355 already cached.
# Batch 72: 356-360 already cached.
# Batch 73: 361-365 already cached.
# Batch 74: 366-370 already cached.
# Batch 75: 371-375 already cached.
# Batch 76: 376-380 already cached.
# Batch 77: 381-385 already cached.
# Batch 78: 386-390 already cached.
# Batch 79: 391-395 already cached.
# Batch 80: 396-400 already cached.
# Batch 81: 401-405 already cached.
# Batch 82: 406-410 already cached.
# Batch 83: 411-415 already cached.
# Batch 84: 416-419 already cached.

# %% [markdown]
# ### <b> <span style="color:pink">1.5 Get Market Price and Demand Data</span></b>

# %% [markdown]
# - Market data was retrieved from the OpenElectricity API, focusing on two key metrics which are price and demand_energy at five-minute intervals for the NEM network.
# - The data was then flattened and cleaned into a structured format containing timestamp, network region, metric, and value.
# - The dataset was stored in wide formats to support integration and analysis.

# %%
# UTC window covers 1–7 Oct in Australia/Sydney (UTC+10) with respecting the API's 7-day limit for 5m interval

START_UTC = "2025-10-01"
END_UTC   = "2025-10-08"

market_df = fetch_market_data(
    network="NEM",
    start_utc=START_UTC,
    end_utc=END_UTC,
    metrics=("price", "demand_energy"),
    interval="5m",
    primary_grouping="network_region"
)

print("Raw market rows:", len(market_df))
print("Columns:", list(market_df.columns))
display(market_df.head())
# Out:
# Response status: 200
# Response url: https://api.openelectricity.org.au/v4/market/network/NEM?metrics=price&metrics=demand_energy&interval=5m&date_start=2025-10-01&date_end=2025-10-08&primary_grouping=network_region&with_clerk=false
# Raw market rows: 20160
# Columns: ['timestamp', 'network_region', 'metric', 'value']
#                   timestamp network_region         metric    value
# 0 2025-09-30 14:00:00+00:00           NSW1          price  56.9800
# 1 2025-09-30 14:00:00+00:00           NSW1  demand_energy   0.5931
# 2 2025-09-30 14:00:00+00:00           QLD1          price  54.8200
# 3 2025-09-30 14:00:00+00:00           QLD1  demand_energy   0.5015
# 4 2025-09-30 14:00:00+00:00            SA1          price   8.1100

# %% [markdown]
# ## <b> <span style="color:orange">2. Data Integration and Caching</span></b>

# %% [markdown]
# For power and emission data per facility, we need to perform some pre-processing to store them into a cached csv file. Specifically, for this process we need to:
# 1. Combine all cached .json data of into one dataframe.
# 2. Sum the facilitiy data to get total power and emissions per facility (some facilities have more than one units).
# 3. Append additional information to each facility (e.g. lat, lon, facility_name, etc).

# %%
# combine all json cache into one dataframe
records = []
for path in glob.glob("./DATA/EXTRACTED/*.json"):
    payload = json.load(open(path))
    
    records.extend(flatten(payload))

series_df = pd.DataFrame(records)

lookup = pd.read_csv("./DATA/EXTRACTED/electricity_units_facilities.csv")[["unit_code","facility_code"]]
series_df = series_df.merge(lookup, on="unit_code", how="left")
facility_df = (series_df.groupby(["timestamp","facility_code","metric"], as_index=False)["value"].sum())

facilities_df = pd.read_csv("./DATA/EXTRACTED/electricity_facilities_matched.csv")[
    ["facility_code", "facility_name", "network_region", "lat", "lng", "fuel_type"]
]
facility_df = facility_df.merge(facilities_df, on="facility_code", how="left")

# reorder columns for clarity
facility_df = facility_df[
    [
        "timestamp", "facility_code",
        "lat", "lng", "metric", "value"
    ]
]

# %%
pivot_df = (
    facility_df
    .pivot_table(
        index=[
            "timestamp", "facility_code"
        ],
        columns="metric",
        values="value"
    )
    .reset_index()
)

pivot_df.columns.name = None  # remove 'metric' label
pivot_df = pivot_df.rename_axis(None, axis=1)

# %%
pivot_df["timestamp"] = pd.to_datetime(pivot_df["timestamp"])
pivot_df.dtypes
# Out:
# timestamp        datetime64[ns, UTC+10:00]
# facility_code                       object
# emissions                          float64
# power                              float64
# dtype: object

# %%
# save to csv
save_dataset(pivot_df, "DATA/EXTRACTED/consolidated_facilities_cleaned.csv")
# Out:
# Saved: DATA\EXTRACTED\consolidated_facilities_cleaned.csv

# %% [markdown]
# Next, we append the matket price and demand to each row.

# %%
# Standardise & make local timestamp
mkt = market_df.copy()
mkt["timestamp"] = pd.to_datetime(mkt["timestamp"], utc=True, errors="coerce")
mkt["timestamp"] = mkt["timestamp"].dt.tz_convert("Australia/Sydney")

# Pivot by timestamp_utc, region to price and demand_energy
market_wide = (
    mkt.pivot_table(index=["timestamp", "network_region"],
                    columns="metric",
                    values="value",
                    aggfunc="first")
       .reset_index()
)

market_wide
# Out:
# metric                 timestamp network_region  demand_energy   price
# 0      2025-10-01 00:00:00+10:00           NSW1         0.5931   56.98
# 1      2025-10-01 00:00:00+10:00           QLD1         0.5015   54.82
# 2      2025-10-01 00:00:00+10:00            SA1         0.1309    8.11
# 3      2025-10-01 00:00:00+10:00           TAS1         0.0749    0.12
# 4      2025-10-01 00:00:00+10:00           VIC1         0.4095    8.95
# ...                          ...            ...            ...     ...
# 10055  2025-10-08 00:55:00+11:00           NSW1         0.5814   94.22
# 10056  2025-10-08 00:55:00+11:00           QLD1         0.5143   65.83
# 10057  2025-10-08 00:55:00+11:00            SA1         0.1144  220.66
# 10058  2025-10-08 00:55:00+11:00           TAS1         0.0771    0.06
# 10059  2025-10-08 00:55:00+11:00           VIC1         0.3830   82.83
#
# [10060 rows x 4 columns]

# %%
# save to csv
save_dataset(market_wide, "DATA/EXTRACTED/consolidated_market_cleaned.csv")
# Out:
# Saved: DATA\EXTRACTED\consolidated_market_cleaned.csv

# %% [markdown]
# ## <b> <span style="color:orange">3. Data Publishing via MTQQ</span></b>

# %%
import mtqq_publisher as publisher
importlib.reload(publisher)
# Out:
# <module 'mtqq_publisher' from 'd:\\Rengga\\venv\\DE\\Assignment 2_Tut07_G04\\mtqq_publisher.py'>

# %%
facility_df = pd.read_csv("DATA/EXTRACTED/consolidated_facilities_cleaned.csv")
market_df = pd.read_csv("DATA/EXTRACTED/consolidated_market_cleaned.csv")

publisher.publish_via_mqtt_broker(facility_df, market_df)
# Out:
# Starting continuous data stream publisher...
#
# Clearing retained messages from broker...
#   ✓ Cleared: COMP5339/T07G04/market/NSW1
#   ✓ Cleared: COMP5339/T07G04/market/QLD1
#   ✓ Cleared: COMP5339/T07G04/market/VIC1
#   ✓ Cleared: COMP5339/T07G04/market/SA1
#   ✓ Cleared: COMP5339/T07G04/market/TAS1
#   ✓ Cleared: COMP5339/T07G04/facilities
# ✓ All retained messages cleared
#
# Connected with result code Success
# Loaded 668353 facility records
# Loaded 10060 market records
#
# [ITERATION 1] Publishing data stream...
# [PUBLISHED] Market: NSW1 @ 2025-10-01 00:00:00+10:00
# [PUBLISHED] Market: QLD1 @ 2025-10-01 00:00:00+10:00
# [PUBLISHED] Market: SA1 @ 2025-10-01 00:00:00+10:00
# [PUBLISHED] Market: TAS1 @ 2025-10-01 00:00:00+10:00
# [PUBLISHED] Market: VIC1 @ 2025-10-01 00:00:00+10:00
# [FIRST] Facility: 0MREH @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: 0MREHA2 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: 0TARONGBESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: 0WAMBOWF @ 2025-10-01 00:00:00+10:00 (power=65.23, emissions=0.0)
# [FIRST] Facility: ADP @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: AGLHAL @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: AGLSOM @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: ALDGASF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: ANGASTON @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: ARWF @ 2025-10-01 00:00:00+10:00 (power=35.4, emissions=0.0)
# [FIRST] Facility: AVLSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: B2PS @ 2025-10-01 00:00:00+10:00 (power=0.0806, emissions=0.0039)
# [FIRST] Facility: BALBESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BANGOWF @ 2025-10-01 00:00:00+10:00 (power=172.3983, emissions=0.0)
# [FIRST] Facility: BANNSP @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BARCALDN @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BARCSF @ 2025-10-01 00:00:00+10:00 (power=0.1, emissions=0.0)
# [FIRST] Facility: BARKIPS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BARRON @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BASTYAN @ 2025-10-01 00:00:00+10:00 (power=57.1, emissions=0.0)
# [FIRST] Facility: BAYSW @ 2025-10-01 00:00:00+10:00 (power=1715.4437, emissions=127.5004)
# [FIRST] Facility: BBATTERY @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BBP31 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BERYLSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BHB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BHILLGT @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BHWF @ 2025-10-01 00:00:00+10:00 (power=7.764, emissions=0.0)
# [FIRST] Facility: BIALAWF @ 2025-10-01 00:00:00+10:00 (power=69.1715, emissions=0.0)
# [FIRST] Facility: BLUEGSF @ 2025-10-01 00:00:00+10:00 (power=0.1009, emissions=0.0)
# [FIRST] Facility: BLUFF @ 2025-10-01 00:00:00+10:00 (power=46.5, emissions=0.0)
# [FIRST] Facility: BLYTHB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BNGSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BNGSF2 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BOCOROCK @ 2025-10-01 00:00:00+10:00 (power=54.23, emissions=0.0)
# [FIRST] Facility: BODWF @ 2025-10-01 00:00:00+10:00 (power=45.1922, emissions=0.0)
# [FIRST] Facility: BOLIVAR @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BOLIVPS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BOMENSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BRAEMARA @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BRNDBES @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BROKENH @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: BRYB1WF1 @ 2025-10-01 00:00:00+10:00 (power=206.7964, emissions=0.0)
# [FIRST] Facility: BULGANA @ 2025-10-01 00:00:00+10:00 (power=42.61, emissions=0.0)
# [FIRST] Facility: BUTLERSG @ 2025-10-01 00:00:00+10:00 (power=6.4, emissions=0.0)
# [FIRST] Facility: BWTR1 @ 2025-10-01 00:00:00+10:00 (power=-25.3219, emissions=0.0)
# [FIRST] Facility: CALLIDEC1 @ 2025-10-01 00:00:00+10:00 (power=398.75, emissions=29.4743)
# [FIRST] Facility: CALL_B @ 2025-10-01 00:00:00+10:00 (power=557.5999999999999, emissions=44.4036)
# [FIRST] Facility: CANUNDA1 @ 2025-10-01 00:00:00+10:00 (power=26.9314, emissions=0.0)
# [FIRST] Facility: CAPBES @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CAPTL_WF @ 2025-10-01 00:00:00+10:00 (power=114.2947, emissions=0.0)
# [FIRST] Facility: CATHROCK @ 2025-10-01 00:00:00+10:00 (power=40.0, emissions=0.0)
# [FIRST] Facility: CBWWBA @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CETHANA @ 2025-10-01 00:00:00+10:00 (power=47.4704, emissions=0.0)
# [FIRST] Facility: CHALLWF @ 2025-10-01 00:00:00+10:00 (power=26.7, emissions=0.0)
# [FIRST] Facility: CHBESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CHILDSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CHYTWF @ 2025-10-01 00:00:00+10:00 (power=11.31, emissions=0.0)
# [FIRST] Facility: CLARESF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CLEMGPWF @ 2025-10-01 00:00:00+10:00 (power=50.6406, emissions=0.0)
# [FIRST] Facility: CLERMSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CLOVER @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CLRKCWF @ 2025-10-01 00:00:00+10:00 (power=338.8702, emissions=0.0)
# [FIRST] Facility: CLUNY @ 2025-10-01 00:00:00+10:00 (power=18.0641, emissions=0.0)
# [FIRST] Facility: COHUNSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: COLEASF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: COLONGRA @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: COLUMSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: COLWF01 @ 2025-10-01 00:00:00+10:00 (power=115.9564, emissions=0.0)
# [FIRST] Facility: CONDONG1 @ 2025-10-01 00:00:00+10:00 (power=20.88, emissions=0.0637)
# [FIRST] Facility: COOPGWF @ 2025-10-01 00:00:00+10:00 (power=328.52, emissions=0.0)
# [FIRST] Facility: CPSA @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CROOKWF2 @ 2025-10-01 00:00:00+10:00 (power=76.6131, emissions=0.0)
# [FIRST] Facility: CROOKWF3 @ 2025-10-01 00:00:00+10:00 (power=41.5434, emissions=0.0)
# [FIRST] Facility: CROWLWF @ 2025-10-01 00:00:00+10:00 (power=58.2636, emissions=0.0)
# [FIRST] Facility: CRURWF1 @ 2025-10-01 00:00:00+10:00 (power=124.8967, emissions=0.0)
# [FIRST] Facility: CRWASF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CSPVPS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: CTHLWF @ 2025-10-01 00:00:00+10:00 (power=14.2611, emissions=0.0)
# [FIRST] Facility: CULLERIN @ 2025-10-01 00:00:00+10:00 (power=24.09, emissions=0.0)
# [FIRST] Facility: DALNTH @ 2025-10-01 00:00:00+10:00 (power=0.1678, emissions=0.0)
# [FIRST] Facility: DARLSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: DARTM @ 2025-10-01 00:00:00+10:00 (power=109.8, emissions=0.0)
# [FIRST] Facility: DAYDSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: DDPS1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: DDSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: DEIBDL @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: DEVILS_G @ 2025-10-01 00:00:00+10:00 (power=46.1123, emissions=0.0)
# [FIRST] Facility: DIAPURWF @ 2025-10-01 00:00:00+10:00 (power=7.3, emissions=0.0)
# [FIRST] Facility: DPNTB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: DRYCGT @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: DULAWF @ 2025-10-01 00:00:00+10:00 (power=172.8, emissions=0.0)
# [FIRST] Facility: DUNDWF @ 2025-10-01 00:00:00+10:00 (power=136.26999999999998, emissions=0.0)
# [FIRST] Facility: EDENVSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: EILDON @ 2025-10-01 00:00:00+10:00 (power=47.0, emissions=0.0)
# [FIRST] Facility: ELAINEWF @ 2025-10-01 00:00:00+10:00 (power=38.66, emissions=0.0)
# [FIRST] Facility: EMERASF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: ERARING @ 2025-10-01 00:00:00+10:00 (power=1259.3821, emissions=93.6141)
# [FIRST] Facility: ERB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: ERGT01 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: FINLEYSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: FISHER @ 2025-10-01 00:00:00+10:00 (power=44.87, emissions=0.0)
# [FIRST] Facility: FLYCRKWF @ 2025-10-01 00:00:00+10:00 (power=8.72, emissions=0.0)
# [FIRST] Facility: GANGARR @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GANNBESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GANNSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GERMCRK @ 2025-10-01 00:00:00+10:00 (power=16.488, emissions=0.7773)
# [FIRST] Facility: GIRGSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GLENSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GLRWNSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GNNDHSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GOONUMSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GORDON @ 2025-10-01 00:00:00+10:00 (power=24.423, emissions=0.0)
# [FIRST] Facility: GPWFEST @ 2025-10-01 00:00:00+10:00 (power=499.16, emissions=0.0)
# [FIRST] Facility: GRANWF @ 2025-10-01 00:00:00+10:00 (power=31.22, emissions=0.0)
# [FIRST] Facility: GREENB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: GRIFSF @ 2025-10-01 00:00:00+10:00 (power=0.0015, emissions=0.0)
# [FIRST] Facility: GSTONE @ 2025-10-01 00:00:00+10:00 (power=750.4628, emissions=61.0252)
# [FIRST] Facility: GSWF @ 2025-10-01 00:00:00+10:00 (power=390.54, emissions=0.0)
# [FIRST] Facility: GULLRGWF @ 2025-10-01 00:00:00+10:00 (power=119.0632, emissions=0.0)
# [FIRST] Facility: GUNNING @ 2025-10-01 00:00:00+10:00 (power=34.6781, emissions=0.0)
# [FIRST] Facility: HALLWF @ 2025-10-01 00:00:00+10:00 (power=74.15, emissions=0.0)
# [FIRST] Facility: HALLWF2 @ 2025-10-01 00:00:00+10:00 (power=56.52, emissions=0.0)
# [FIRST] Facility: HAMISF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HAUGHT1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HAYMSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HBESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HD1WF @ 2025-10-01 00:00:00+10:00 (power=45.06, emissions=0.0)
# [FIRST] Facility: HEZ @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HILLSTN @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HORNSDAL @ 2025-10-01 00:00:00+10:00 (power=90.3, emissions=0.0)
# [FIRST] Facility: HORNSDAL2 @ 2025-10-01 00:00:00+10:00 (power=96.5, emissions=0.0)
# [FIRST] Facility: HORNSDAL3 @ 2025-10-01 00:00:00+10:00 (power=107.6, emissions=0.0)
# [FIRST] Facility: HORNSDPR @ 2025-10-01 00:00:00+10:00 (power=16.4, emissions=0.0)
# [FIRST] Facility: HUGSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HUMENSW @ 2025-10-01 00:00:00+10:00 (power=21.0275, emissions=0.0)
# [FIRST] Facility: HUMEV @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HUNTER @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: HVWW @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: JBUTTERS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: JEERA @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: JEERB @ 2025-10-01 00:00:00+10:00 (power=0.1, emissions=0.0067)
# [FIRST] Facility: JEMALNG1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: JUNEESF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: KABANWF @ 2025-10-01 00:00:00+10:00 (power=110.789, emissions=0.0)
# [FIRST] Facility: KAREEYA @ 2025-10-01 00:00:00+10:00 (power=85.685, emissions=0.0)
# [FIRST] Facility: KARSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: KENNEDY @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: KERNGSP @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: KESS1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: KIAMSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: KIATAWF @ 2025-10-01 00:00:00+10:00 (power=29.3, emissions=0.0)
# [FIRST] Facility: KINGASF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: KOGANCK @ 2025-10-01 00:00:00+10:00 (power=719.9396, emissions=50.6118)
# [FIRST] Facility: KSP1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: LADBROKE @ 2025-10-01 00:00:00+10:00 (power=0.02, emissions=0.0008)
# [FIRST] Facility: LBBESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: LEM_WIL @ 2025-10-01 00:00:00+10:00 (power=86.9284, emissions=0.0)
# [FIRST] Facility: LGAPWF1 @ 2025-10-01 00:00:00+10:00 (power=113.57, emissions=0.0)
# [FIRST] Facility: LILYVASF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: LIMOSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: LIMOSF2 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: LI_WY_CA @ 2025-10-01 00:00:00+10:00 (power=154.4835, emissions=0.0)
# [FIRST] Facility: LKBONNY1 @ 2025-10-01 00:00:00+10:00 (power=41.9754, emissions=0.0)
# [FIRST] Facility: LKBONNY3 @ 2025-10-01 00:00:00+10:00 (power=16.7466, emissions=0.0)
# [FIRST] Facility: LKBONNY_2 @ 2025-10-01 00:00:00+10:00 (power=87.0093, emissions=0.0)
# [FIRST] Facility: LK_ECHO @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: LNGS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: LONSDALE @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: LOYYANGA @ 2025-10-01 00:00:00+10:00 (power=1252.0, emissions=121.1206)
# [FIRST] Facility: LOYYB @ 2025-10-01 00:00:00+10:00 (power=905.25, emissions=84.6635)
# [FIRST] Facility: LRSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MACARTH @ 2025-10-01 00:00:00+10:00 (power=126.2, emissions=0.0)
# [FIRST] Facility: MACKNTSH @ 2025-10-01 00:00:00+10:00 (power=51.81, emissions=0.0)
# [FIRST] Facility: MANNSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MANNUMB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MANSLR @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MAPS2 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MARYRSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MBAHNTH @ 2025-10-01 00:00:00+10:00 (power=20.2, emissions=1.0736)
# [FIRST] Facility: MBPS2 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MCINTYR @ 2025-10-01 00:00:00+10:00 (power=139.076, emissions=0.0)
# [FIRST] Facility: MCKAY @ 2025-10-01 00:00:00+10:00 (power=0.02, emissions=0.0)
# [FIRST] Facility: MEADOWBK @ 2025-10-01 00:00:00+10:00 (power=43.4416, emissions=0.0)
# [FIRST] Facility: METZSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MEWF @ 2025-10-01 00:00:00+10:00 (power=49.5002, emissions=0.0)
# [FIRST] Facility: MIDDLSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MILLMERN @ 2025-10-01 00:00:00+10:00 (power=431.0752, emissions=30.0782)
# [FIRST] Facility: MINTARO @ 2025-10-01 00:00:00+10:00 (power=0.0854, emissions=0.0061)
# [FIRST] Facility: MLSP @ 2025-10-01 00:00:00+10:00 (power=0.013, emissions=0.0)
# [FIRST] Facility: MLWF @ 2025-10-01 00:00:00+10:00 (power=11.55, emissions=0.0)
# [FIRST] Facility: MOKOSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MOLNGSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MOORAWF1 @ 2025-10-01 00:00:00+10:00 (power=248.89, emissions=0.0)
# [FIRST] Facility: MOREESF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MORTLK @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MOUSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MP @ 2025-10-01 00:00:00+10:00 (power=895.8877, emissions=64.8846)
# [FIRST] Facility: MREHA3 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MRTLSWF @ 2025-10-01 00:00:00+10:00 (power=89.57, emissions=0.0)
# [FIRST] Facility: MSTUART @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MTGELWF @ 2025-10-01 00:00:00+10:00 (power=59.5233, emissions=0.0)
# [FIRST] Facility: MTMERCER @ 2025-10-01 00:00:00+10:00 (power=78.1, emissions=0.0)
# [FIRST] Facility: MTMILLAR @ 2025-10-01 00:00:00+10:00 (power=34.0, emissions=0.0)
# [FIRST] Facility: MUCRKSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MURRAY @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: MUSSELRO @ 2025-10-01 00:00:00+10:00 (power=46.0, emissions=0.0)
# [FIRST] Facility: MUWAWF @ 2025-10-01 00:00:00+10:00 (power=379.9500000000001, emissions=0.0)
# [FIRST] Facility: MWPS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: NBHWF @ 2025-10-01 00:00:00+10:00 (power=106.2, emissions=0.0)
# [FIRST] Facility: NEVERSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: NEWENSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: NEWPORT @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: NPPPPS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: NUMURKSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: NYNGAN @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: OAKEY @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: OAKEY1SF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: OAKEY2SF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: OAKLAND @ 2025-10-01 00:00:00+10:00 (power=34.4, emissions=0.0)
# [FIRST] Facility: OSBORNE @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: PALOONA @ 2025-10-01 00:00:00+10:00 (power=29.41, emissions=0.0)
# [FIRST] Facility: PAREPW @ 2025-10-01 00:00:00+10:00 (power=48.43, emissions=0.0)
# [FIRST] Facility: PIBESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: PIONEER @ 2025-10-01 00:00:00+10:00 (power=43.2, emissions=0.0724)
# [FIRST] Facility: PORTLCN @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: PORTWF @ 2025-10-01 00:00:00+10:00 (power=59.0, emissions=0.0)
# [FIRST] Facility: PSF @ 2025-10-01 00:00:00+10:00 (power=0.0015, emissions=0.0)
# [FIRST] Facility: PTINA @ 2025-10-01 00:00:00+10:00 (power=3.31, emissions=0.0)
# [FIRST] Facility: QBYNB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: QUARANTN @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: RANGEB @ 2025-10-01 00:00:00+10:00 (power=0.1, emissions=0.0)
# [FIRST] Facility: REECE @ 2025-10-01 00:00:00+10:00 (power=118.8699, emissions=0.0)
# [FIRST] Facility: REPULSE @ 2025-10-01 00:00:00+10:00 (power=32.8856, emissions=0.0)
# [FIRST] Facility: RESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: RIVNB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: ROMA @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: ROWALLAN @ 2025-10-01 00:00:00+10:00 (power=-0.0049, emissions=0.0)
# [FIRST] Facility: ROYALLA @ 2025-10-01 00:00:00+10:00 (power=0.001, emissions=0.0)
# [FIRST] Facility: RPCG @ 2025-10-01 00:00:00+10:00 (power=13.8, emissions=0.0509)
# [FIRST] Facility: RRSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: RUBICON @ 2025-10-01 00:00:00+10:00 (power=0.585, emissions=0.0)
# [FIRST] Facility: RUGBYR @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: RYANCWF @ 2025-10-01 00:00:00+10:00 (power=75.16, emissions=0.0)
# [FIRST] Facility: RYEPARK @ 2025-10-01 00:00:00+10:00 (power=202.6951, emissions=0.0)
# [FIRST] Facility: SALTCRK @ 2025-10-01 00:00:00+10:00 (power=15.35, emissions=0.0)
# [FIRST] Facility: SAPHWF1 @ 2025-10-01 00:00:00+10:00 (power=233.2479, emissions=0.0)
# [FIRST] Facility: SEBSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SHOAL @ 2025-10-01 00:00:00+10:00 (power=43.47, emissions=2.1815)
# [FIRST] Facility: SHOALHAV @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SITHE @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SMCSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SMTHBES1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SNAPPER @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SNB1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SNOWNTH @ 2025-10-01 00:00:00+10:00 (power=126.7, emissions=0.0)
# [FIRST] Facility: SNOWSTH @ 2025-10-01 00:00:00+10:00 (power=114.5, emissions=0.0)
# [FIRST] Facility: SNOWTOWN @ 2025-10-01 00:00:00+10:00 (power=92.5856, emissions=0.0)
# [FIRST] Facility: SNOWY2 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SNOWY3 @ 2025-10-01 00:00:00+10:00 (power=61.8, emissions=0.0)
# [FIRST] Facility: SNOWY6 @ 2025-10-01 00:00:00+10:00 (power=52.6, emissions=0.0)
# [FIRST] Facility: SNUG @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SRSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: STANVAC @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: STANWELL @ 2025-10-01 00:00:00+10:00 (power=892.8367000000001, emissions=63.7708)
# [FIRST] Facility: STARFHILL @ 2025-10-01 00:00:00+10:00 (power=6.6981, emissions=0.0)
# [FIRST] Facility: STOCKYD @ 2025-10-01 00:00:00+10:00 (power=337.78, emissions=0.0)
# [FIRST] Facility: STWF @ 2025-10-01 00:00:00+10:00 (power=136.271, emissions=0.0)
# [FIRST] Facility: SUNRSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SUNTPSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: SWAN_E @ 2025-10-01 00:00:00+10:00 (power=-0.58, emissions=0.0)
# [FIRST] Facility: TALLAWAR @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: TALWB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: TARALGA @ 2025-10-01 00:00:00+10:00 (power=48.6976, emissions=0.0)
# [FIRST] Facility: TARONG @ 2025-10-01 00:00:00+10:00 (power=659.1, emissions=48.5372)
# [FIRST] Facility: TARONGN @ 2025-10-01 00:00:00+10:00 (power=278.5, emissions=19.5832)
# [FIRST] Facility: TARRALEA @ 2025-10-01 00:00:00+10:00 (power=59.7, emissions=0.0)
# [FIRST] Facility: TB2SF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: TBSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: TIB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: TORRIS @ 2025-10-01 00:00:00+10:00 (power=40.0, emissions=1.9193)
# [FIRST] Facility: TREVALLN @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: TRIBUTE @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: TULLYSM @ 2025-10-01 00:00:00+10:00 (power=9.9, emissions=0.0149)
# [FIRST] Facility: TUMUT3 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: TUNGATIN @ 2025-10-01 00:00:00+10:00 (power=80.25, emissions=0.0)
# [FIRST] Facility: TVCCPS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: ULBESS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: URANQ @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: VBB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: VP @ 2025-10-01 00:00:00+10:00 (power=597.0642, emissions=49.1433)
# [FIRST] Facility: VPGS @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WAGGNSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WALGRV @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WANDBG @ 2025-10-01 00:00:00+10:00 (power=4.4928, emissions=0.0)
# [FIRST] Facility: WANDSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WARWSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WATERLWF @ 2025-10-01 00:00:00+10:00 (power=103.5, emissions=0.0)
# [FIRST] Facility: WAUBRAWF @ 2025-10-01 00:00:00+10:00 (power=53.4722, emissions=0.0)
# [FIRST] Facility: WDBESS @ 2025-10-01 00:00:00+10:00 (power=0.4866, emissions=0.0)
# [FIRST] Facility: WDBESS2 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WDGPH @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WELLSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WELNSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WEMENSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WGWF @ 2025-10-01 00:00:00+10:00 (power=106.9, emissions=0.0)
# [FIRST] Facility: WHITSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WINTSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WIVENHOE @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WKIEWA @ 2025-10-01 00:00:00+10:00 (power=32.0, emissions=0.0)
# [FIRST] Facility: WLWLSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WNSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WOLARSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WOODLWN @ 2025-10-01 00:00:00+10:00 (power=13.9968, emissions=0.0)
# [FIRST] Facility: WOOLGSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WOOLNTH1 @ 2025-10-01 00:00:00+10:00 (power=25.97, emissions=0.0)
# [FIRST] Facility: WPWF @ 2025-10-01 00:00:00+10:00 (power=44.05, emissions=0.0)
# [FIRST] Facility: WRSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WRWF1 @ 2025-10-01 00:00:00+10:00 (power=36.9018, emissions=0.0)
# [FIRST] Facility: WSTWYSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WTAHB @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WUNUSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: WYASF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: YABULU @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: YALLOURN @ 2025-10-01 00:00:00+10:00 (power=609.9063, emissions=66.0681)
# [FIRST] Facility: YAMBUK @ 2025-10-01 00:00:00+10:00 (power=4.9, emissions=0.0)
# [FIRST] Facility: YARANSF @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: YARWUN @ 2025-10-01 00:00:00+10:00 (power=85.01, emissions=4.344)
# [FIRST] Facility: YATSF1 @ 2025-10-01 00:00:00+10:00 (power=0.0, emissions=0.0)
# [FIRST] Facility: YENDONWF @ 2025-10-01 00:00:00+10:00 (power=94.95, emissions=0.0)
# [FIRST] Facility: YSWF @ 2025-10-01 00:00:00+10:00 (power=20.2, emissions=0.0)
# [PUBLISHED] Market: NSW1 @ 2025-10-01 00:05:00+10:00
# [PUBLISHED] Market: QLD1 @ 2025-10-01 00:05:00+10:00
# [PUBLISHED] Market: SA1 @ 2025-10-01 00:05:00+10:00
# [PUBLISHED] Market: TAS1 @ 2025-10-01 00:05:00+10:00
# [PUBLISHED] Market: VIC1 @ 2025-10-01 00:05:00+10:00
# [SKIPPED] Facility: 0MREH @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: 0MREHA2 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: 0TARONGBESS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: 0WAMBOWF @ 2025-10-01 00:05:00+10:00 (power=64.647, emissions=0.0)
# [SKIPPED] Facility: ADP @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: AGLHAL @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: AGLSOM @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: ALDGASF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: ANGASTON @ 2025-10-01 00:05:00+10:00 (power=-0.1, emissions=0.0)
# [UPDATED] Facility: ARWF @ 2025-10-01 00:05:00+10:00 (power=33.3, emissions=0.0)
# [SKIPPED] Facility: AVLSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: B2PS @ 2025-10-01 00:05:00+10:00 (current: power=0.0806, emissions=0.0039 | previous: power=0.0806, emissions=0.0039)
# [SKIPPED] Facility: BALBESS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: BANGOWF @ 2025-10-01 00:05:00+10:00 (power=169.2969, emissions=0.0)
# [SKIPPED] Facility: BANNSP @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BARCALDN @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BARCSF @ 2025-10-01 00:05:00+10:00 (current: power=0.1, emissions=0.0 | previous: power=0.1, emissions=0.0)
# [SKIPPED] Facility: BARKIPS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BARRON @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: BASTYAN @ 2025-10-01 00:05:00+10:00 (power=62.41, emissions=0.0)
# [UPDATED] Facility: BAYSW @ 2025-10-01 00:05:00+10:00 (power=1702.5041, emissions=127.0194)
# [SKIPPED] Facility: BBATTERY @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BBP31 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BERYLSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BHB @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BHILLGT @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: BHWF @ 2025-10-01 00:05:00+10:00 (power=4.476, emissions=0.0)
# [UPDATED] Facility: BIALAWF @ 2025-10-01 00:05:00+10:00 (power=70.0982, emissions=0.0)
# [SKIPPED] Facility: BLUEGSF @ 2025-10-01 00:05:00+10:00 (current: power=0.1009, emissions=0.0 | previous: power=0.1009, emissions=0.0)
# [SKIPPED] Facility: BLUFF @ 2025-10-01 00:05:00+10:00 (current: power=46.5, emissions=0.0 | previous: power=46.5, emissions=0.0)
# [UPDATED] Facility: BLYTHB @ 2025-10-01 00:05:00+10:00 (power=0.22, emissions=0.0)
# [SKIPPED] Facility: BNGSF1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BNGSF2 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: BOCOROCK @ 2025-10-01 00:05:00+10:00 (power=53.98, emissions=0.0)
# [UPDATED] Facility: BODWF @ 2025-10-01 00:05:00+10:00 (power=44.137, emissions=0.0)
# [SKIPPED] Facility: BOLIVAR @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BOLIVPS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BOMENSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BRAEMARA @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BRNDBES @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: BROKENH @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: BRYB1WF1 @ 2025-10-01 00:05:00+10:00 (power=210.1533, emissions=0.0)
# [UPDATED] Facility: BULGANA @ 2025-10-01 00:05:00+10:00 (power=47.56, emissions=0.0)
# [UPDATED] Facility: BUTLERSG @ 2025-10-01 00:05:00+10:00 (power=6.5, emissions=0.0)
# [UPDATED] Facility: BWTR1 @ 2025-10-01 00:05:00+10:00 (power=-23.8357, emissions=0.0)
# [UPDATED] Facility: CALLIDEC1 @ 2025-10-01 00:05:00+10:00 (power=400.95, emissions=29.5555)
# [UPDATED] Facility: CALL_B @ 2025-10-01 00:05:00+10:00 (power=559.2, emissions=44.4674)
# [UPDATED] Facility: CANUNDA1 @ 2025-10-01 00:05:00+10:00 (power=34.7405, emissions=0.0)
# [SKIPPED] Facility: CAPBES @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: CAPTL_WF @ 2025-10-01 00:05:00+10:00 (power=115.0135, emissions=0.0)
# [UPDATED] Facility: CATHROCK @ 2025-10-01 00:05:00+10:00 (power=38.7, emissions=0.0)
# [SKIPPED] Facility: CBWWBA @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: CETHANA @ 2025-10-01 00:05:00+10:00 (power=44.4766, emissions=0.0)
# [SKIPPED] Facility: CHALLWF @ 2025-10-01 00:05:00+10:00 (current: power=26.7, emissions=0.0 | previous: power=26.7, emissions=0.0)
# [SKIPPED] Facility: CHBESS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: CHILDSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: CHYTWF @ 2025-10-01 00:05:00+10:00 (power=13.33, emissions=0.0)
# [SKIPPED] Facility: CLARESF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: CLEMGPWF @ 2025-10-01 00:05:00+10:00 (power=52.8017, emissions=0.0)
# [SKIPPED] Facility: CLERMSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: CLOVER @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: CLRKCWF @ 2025-10-01 00:05:00+10:00 (power=331.0692, emissions=0.0)
# [UPDATED] Facility: CLUNY @ 2025-10-01 00:05:00+10:00 (power=18.0687, emissions=0.0)
# [SKIPPED] Facility: COHUNSF1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: COLEASF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: COLONGRA @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: COLUMSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: COLWF01 @ 2025-10-01 00:05:00+10:00 (power=115.1507, emissions=0.0)
# [UPDATED] Facility: CONDONG1 @ 2025-10-01 00:05:00+10:00 (power=20.91, emissions=0.0637)
# [UPDATED] Facility: COOPGWF @ 2025-10-01 00:05:00+10:00 (power=328.94, emissions=0.0)
# [SKIPPED] Facility: CPSA @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: CROOKWF2 @ 2025-10-01 00:05:00+10:00 (power=75.733, emissions=0.0)
# [UPDATED] Facility: CROOKWF3 @ 2025-10-01 00:05:00+10:00 (power=36.6673, emissions=0.0)
# [UPDATED] Facility: CROWLWF @ 2025-10-01 00:05:00+10:00 (power=60.4774, emissions=0.0)
# [UPDATED] Facility: CRURWF1 @ 2025-10-01 00:05:00+10:00 (power=126.3968, emissions=0.0)
# [SKIPPED] Facility: CRWASF1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: CSPVPS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: CTHLWF @ 2025-10-01 00:05:00+10:00 (power=14.6517, emissions=0.0)
# [UPDATED] Facility: CULLERIN @ 2025-10-01 00:05:00+10:00 (power=24.86, emissions=0.0)
# [UPDATED] Facility: DALNTH @ 2025-10-01 00:05:00+10:00 (power=0.1984, emissions=0.0)
# [SKIPPED] Facility: DARLSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: DARTM @ 2025-10-01 00:05:00+10:00 (current: power=109.8, emissions=0.0 | previous: power=109.8, emissions=0.0)
# [SKIPPED] Facility: DAYDSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: DDPS1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: DDSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: DEIBDL @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: DEVILS_G @ 2025-10-01 00:05:00+10:00 (power=34.9864, emissions=0.0)
# [SKIPPED] Facility: DIAPURWF @ 2025-10-01 00:05:00+10:00 (current: power=7.3, emissions=0.0 | previous: power=7.3, emissions=0.0)
# [SKIPPED] Facility: DPNTB @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: DRYCGT @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: DULAWF @ 2025-10-01 00:05:00+10:00 (power=172.9, emissions=0.0)
# [UPDATED] Facility: DUNDWF @ 2025-10-01 00:05:00+10:00 (power=125.68, emissions=0.0)
# [SKIPPED] Facility: EDENVSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: EILDON @ 2025-10-01 00:05:00+10:00 (power=47.04, emissions=0.0)
# [UPDATED] Facility: ELAINEWF @ 2025-10-01 00:05:00+10:00 (power=38.49, emissions=0.0)
# [SKIPPED] Facility: EMERASF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: ERARING @ 2025-10-01 00:05:00+10:00 (power=1219.1471, emissions=92.1187)
# [SKIPPED] Facility: ERB @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: ERGT01 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: FINLEYSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: FISHER @ 2025-10-01 00:05:00+10:00 (power=44.94, emissions=0.0)
# [UPDATED] Facility: FLYCRKWF @ 2025-10-01 00:05:00+10:00 (power=9.88, emissions=0.0)
# [SKIPPED] Facility: GANGARR @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GANNBESS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GANNSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: GERMCRK @ 2025-10-01 00:05:00+10:00 (power=16.882, emissions=0.7865)
# [SKIPPED] Facility: GIRGSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GLENSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GLRWNSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GNNDHSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GOONUMSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: GORDON @ 2025-10-01 00:05:00+10:00 (power=23.837, emissions=0.0)
# [UPDATED] Facility: GPWFEST @ 2025-10-01 00:05:00+10:00 (power=535.77, emissions=0.0)
# [UPDATED] Facility: GRANWF @ 2025-10-01 00:05:00+10:00 (power=30.47, emissions=0.0)
# [SKIPPED] Facility: GREENB @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GRIFSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0015, emissions=0.0 | previous: power=0.0015, emissions=0.0)
# [UPDATED] Facility: GSTONE @ 2025-10-01 00:05:00+10:00 (power=750.5997, emissions=61.0306)
# [UPDATED] Facility: GSWF @ 2025-10-01 00:05:00+10:00 (power=388.45, emissions=0.0)
# [UPDATED] Facility: GULLRGWF @ 2025-10-01 00:05:00+10:00 (power=122.2931, emissions=0.0)
# [UPDATED] Facility: GUNNING @ 2025-10-01 00:05:00+10:00 (power=32.4437, emissions=0.0)
# [UPDATED] Facility: HALLWF @ 2025-10-01 00:05:00+10:00 (power=74.35, emissions=0.0)
# [UPDATED] Facility: HALLWF2 @ 2025-10-01 00:05:00+10:00 (power=56.47, emissions=0.0)
# [SKIPPED] Facility: HAMISF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HAUGHT1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HAYMSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HBESS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: HD1WF @ 2025-10-01 00:05:00+10:00 (power=43.67, emissions=0.0)
# [SKIPPED] Facility: HEZ @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HILLSTN @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: HORNSDAL @ 2025-10-01 00:05:00+10:00 (power=88.1, emissions=0.0)
# [UPDATED] Facility: HORNSDAL2 @ 2025-10-01 00:05:00+10:00 (power=95.7, emissions=0.0)
# [UPDATED] Facility: HORNSDAL3 @ 2025-10-01 00:05:00+10:00 (power=101.4, emissions=0.0)
# [UPDATED] Facility: HORNSDPR @ 2025-10-01 00:05:00+10:00 (power=18.0, emissions=0.0)
# [SKIPPED] Facility: HUGSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: HUMENSW @ 2025-10-01 00:05:00+10:00 (power=20.9967, emissions=0.0)
# [SKIPPED] Facility: HUMEV @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HUNTER @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HVWW @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: JBUTTERS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: JEERA @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: JEERB @ 2025-10-01 00:05:00+10:00 (current: power=0.1, emissions=0.0067 | previous: power=0.1, emissions=0.0067)
# [SKIPPED] Facility: JEMALNG1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: JUNEESF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: KABANWF @ 2025-10-01 00:05:00+10:00 (power=120.224, emissions=0.0)
# [UPDATED] Facility: KAREEYA @ 2025-10-01 00:05:00+10:00 (power=85.8575, emissions=0.0)
# [SKIPPED] Facility: KARSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: KENNEDY @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: KERNGSP @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: KESS1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: KIAMSF1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: KIATAWF @ 2025-10-01 00:05:00+10:00 (power=29.8, emissions=0.0)
# [SKIPPED] Facility: KINGASF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: KOGANCK @ 2025-10-01 00:05:00+10:00 (power=723.2295, emissions=50.7274)
# [SKIPPED] Facility: KSP1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LADBROKE @ 2025-10-01 00:05:00+10:00 (current: power=0.02, emissions=0.0008 | previous: power=0.02, emissions=0.0008)
# [SKIPPED] Facility: LBBESS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: LEM_WIL @ 2025-10-01 00:05:00+10:00 (power=87.1782, emissions=0.0)
# [UPDATED] Facility: LGAPWF1 @ 2025-10-01 00:05:00+10:00 (power=114.91, emissions=0.0)
# [SKIPPED] Facility: LILYVASF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LIMOSF1 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LIMOSF2 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: LI_WY_CA @ 2025-10-01 00:05:00+10:00 (power=154.7149, emissions=0.0)
# [UPDATED] Facility: LKBONNY1 @ 2025-10-01 00:05:00+10:00 (power=45.4585, emissions=0.0)
# [UPDATED] Facility: LKBONNY3 @ 2025-10-01 00:05:00+10:00 (power=17.4165, emissions=0.0)
# [UPDATED] Facility: LKBONNY_2 @ 2025-10-01 00:05:00+10:00 (power=119.535, emissions=0.0)
# [SKIPPED] Facility: LK_ECHO @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LNGS @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LONSDALE @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: LOYYANGA @ 2025-10-01 00:05:00+10:00 (power=1222.0, emissions=119.6693)
# [UPDATED] Facility: LOYYB @ 2025-10-01 00:05:00+10:00 (power=905.625, emissions=84.68119999999999)
# [SKIPPED] Facility: LRSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MACARTH @ 2025-10-01 00:05:00+10:00 (power=121.7, emissions=0.0)
# [UPDATED] Facility: MACKNTSH @ 2025-10-01 00:05:00+10:00 (power=64.98, emissions=0.0)
# [SKIPPED] Facility: MANNSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MANNUMB @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MANSLR @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MAPS2 @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MARYRSF @ 2025-10-01 00:05:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# ...
# [SKIPPED] Facility: GANNBESS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GANNSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: GERMCRK @ 2025-10-01 00:25:00+10:00 (power=16.884, emissions=0.7866)
# [SKIPPED] Facility: GIRGSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GLENSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GLRWNSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GNNDHSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: GOONUMSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: GORDON @ 2025-10-01 00:25:00+10:00 (power=21.7203, emissions=0.0)
# [UPDATED] Facility: GPWFEST @ 2025-10-01 00:25:00+10:00 (power=621.1, emissions=0.0)
# [UPDATED] Facility: GRANWF @ 2025-10-01 00:25:00+10:00 (power=32.2, emissions=0.0)
# [UPDATED] Facility: GREENB @ 2025-10-01 00:25:00+10:00 (power=0.108, emissions=0.0)
# [SKIPPED] Facility: GRIFSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0015, emissions=0.0 | previous: power=0.0015, emissions=0.0)
# [UPDATED] Facility: GSTONE @ 2025-10-01 00:25:00+10:00 (power=548.6181, emissions=52.8186)
# [UPDATED] Facility: GSWF @ 2025-10-01 00:25:00+10:00 (power=393.59, emissions=0.0)
# [UPDATED] Facility: GULLRGWF @ 2025-10-01 00:25:00+10:00 (power=119.1132, emissions=0.0)
# [UPDATED] Facility: GUNNING @ 2025-10-01 00:25:00+10:00 (power=35.1383, emissions=0.0)
# [UPDATED] Facility: HALLWF @ 2025-10-01 00:25:00+10:00 (power=74.07, emissions=0.0)
# [UPDATED] Facility: HALLWF2 @ 2025-10-01 00:25:00+10:00 (power=56.19, emissions=0.0)
# [SKIPPED] Facility: HAMISF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HAUGHT1 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HAYMSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HBESS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: HD1WF @ 2025-10-01 00:25:00+10:00 (power=46.56, emissions=0.0)
# [SKIPPED] Facility: HEZ @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HILLSTN @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: HORNSDAL @ 2025-10-01 00:25:00+10:00 (power=76.7, emissions=0.0)
# [UPDATED] Facility: HORNSDAL2 @ 2025-10-01 00:25:00+10:00 (power=93.9, emissions=0.0)
# [UPDATED] Facility: HORNSDAL3 @ 2025-10-01 00:25:00+10:00 (power=91.9, emissions=0.0)
# [UPDATED] Facility: HORNSDPR @ 2025-10-01 00:25:00+10:00 (power=13.8, emissions=0.0)
# [SKIPPED] Facility: HUGSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: HUMENSW @ 2025-10-01 00:25:00+10:00 (power=21.6427, emissions=0.0)
# [SKIPPED] Facility: HUMEV @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HUNTER @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: HVWW @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: JBUTTERS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: JEERA @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: JEERB @ 2025-10-01 00:25:00+10:00 (current: power=0.1, emissions=0.0067 | previous: power=0.1, emissions=0.0067)
# [SKIPPED] Facility: JEMALNG1 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: JUNEESF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: KABANWF @ 2025-10-01 00:25:00+10:00 (power=118.013, emissions=0.0)
# [UPDATED] Facility: KAREEYA @ 2025-10-01 00:25:00+10:00 (power=85.94, emissions=0.0)
# [SKIPPED] Facility: KARSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: KENNEDY @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: KERNGSP @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: KESS1 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: KIAMSF1 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: KIATAWF @ 2025-10-01 00:25:00+10:00 (power=27.1, emissions=0.0)
# [SKIPPED] Facility: KINGASF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: KOGANCK @ 2025-10-01 00:25:00+10:00 (power=724.0016, emissions=50.7545)
# [SKIPPED] Facility: KSP1 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LADBROKE @ 2025-10-01 00:25:00+10:00 (current: power=0.02, emissions=0.0008 | previous: power=0.02, emissions=0.0008)
# [SKIPPED] Facility: LBBESS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: LEM_WIL @ 2025-10-01 00:25:00+10:00 (power=86.7541, emissions=0.0)
# [UPDATED] Facility: LGAPWF1 @ 2025-10-01 00:25:00+10:00 (power=112.04, emissions=0.0)
# [SKIPPED] Facility: LILYVASF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LIMOSF1 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LIMOSF2 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: LI_WY_CA @ 2025-10-01 00:25:00+10:00 (power=153.8733, emissions=0.0)
# [UPDATED] Facility: LKBONNY1 @ 2025-10-01 00:25:00+10:00 (power=29.3828, emissions=0.0)
# [UPDATED] Facility: LKBONNY3 @ 2025-10-01 00:25:00+10:00 (power=18.7562, emissions=0.0)
# [UPDATED] Facility: LKBONNY_2 @ 2025-10-01 00:25:00+10:00 (power=62.0859, emissions=0.0)
# [SKIPPED] Facility: LK_ECHO @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LNGS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: LONSDALE @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: LOYYANGA @ 2025-10-01 00:25:00+10:00 (power=1076.0, emissions=112.6072)
# [UPDATED] Facility: LOYYB @ 2025-10-01 00:25:00+10:00 (power=906.75, emissions=84.7337)
# [SKIPPED] Facility: LRSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MACARTH @ 2025-10-01 00:25:00+10:00 (power=94.0, emissions=0.0)
# [UPDATED] Facility: MACKNTSH @ 2025-10-01 00:25:00+10:00 (power=66.16, emissions=0.0)
# [SKIPPED] Facility: MANNSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MANNUMB @ 2025-10-01 00:25:00+10:00 (power=5.0, emissions=0.0)
# [SKIPPED] Facility: MANSLR @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MAPS2 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MARYRSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MBAHNTH @ 2025-10-01 00:25:00+10:00 (power=20.6, emissions=1.0843)
# [SKIPPED] Facility: MBPS2 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MCINTYR @ 2025-10-01 00:25:00+10:00 (power=139.248, emissions=0.0)
# [SKIPPED] Facility: MCKAY @ 2025-10-01 00:25:00+10:00 (current: power=0.02, emissions=0.0 | previous: power=0.02, emissions=0.0)
# [UPDATED] Facility: MEADOWBK @ 2025-10-01 00:25:00+10:00 (power=43.6131, emissions=0.0)
# [SKIPPED] Facility: METZSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MEWF @ 2025-10-01 00:25:00+10:00 (power=53.7518, emissions=0.0)
# [SKIPPED] Facility: MIDDLSF1 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MILLMERN @ 2025-10-01 00:25:00+10:00 (power=434.9359, emissions=30.213)
# [SKIPPED] Facility: MINTARO @ 2025-10-01 00:25:00+10:00 (current: power=0.0854, emissions=0.0061 | previous: power=0.0854, emissions=0.0061)
# [SKIPPED] Facility: MLSP @ 2025-10-01 00:25:00+10:00 (current: power=0.013, emissions=0.0 | previous: power=0.013, emissions=0.0)
# [UPDATED] Facility: MLWF @ 2025-10-01 00:25:00+10:00 (power=14.82, emissions=0.0)
# Published 1000/678413 records...
# [SKIPPED] Facility: MOKOSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# Published 1000/678413 records...
# [SKIPPED] Facility: MOLNGSF1 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# Published 1000/678413 records...
# [UPDATED] Facility: MOORAWF1 @ 2025-10-01 00:25:00+10:00 (power=230.8, emissions=0.0)
# [SKIPPED] Facility: MOREESF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MORTLK @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MOUSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MP @ 2025-10-01 00:25:00+10:00 (power=697.5935999999999, emissions=57.70399999999999)
# [SKIPPED] Facility: MREHA3 @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MRTLSWF @ 2025-10-01 00:25:00+10:00 (power=54.33, emissions=0.0)
# [SKIPPED] Facility: MSTUART @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MTGELWF @ 2025-10-01 00:25:00+10:00 (power=96.4599, emissions=0.0)
# [UPDATED] Facility: MTMERCER @ 2025-10-01 00:25:00+10:00 (power=79.3, emissions=0.0)
# [UPDATED] Facility: MTMILLAR @ 2025-10-01 00:25:00+10:00 (power=32.1, emissions=0.0)
# [SKIPPED] Facility: MUCRKSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: MURRAY @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: MUSSELRO @ 2025-10-01 00:25:00+10:00 (power=25.6, emissions=0.0)
# [UPDATED] Facility: MUWAWF @ 2025-10-01 00:25:00+10:00 (power=365.53, emissions=0.0)
# [SKIPPED] Facility: MWPS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: NBHWF @ 2025-10-01 00:25:00+10:00 (power=103.0, emissions=0.0)
# [SKIPPED] Facility: NEVERSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: NEWENSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: NEWPORT @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: NPPPPS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: NUMURKSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: NYNGAN @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: OAKEY @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: OAKEY1SF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: OAKEY2SF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: OAKLAND @ 2025-10-01 00:25:00+10:00 (power=35.5, emissions=0.0)
# [SKIPPED] Facility: OSBORNE @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: PALOONA @ 2025-10-01 00:25:00+10:00 (power=29.74, emissions=0.0)
# [UPDATED] Facility: PAREPW @ 2025-10-01 00:25:00+10:00 (power=30.94, emissions=0.0)
# [SKIPPED] Facility: PIBESS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: PIONEER @ 2025-10-01 00:25:00+10:00 (power=41.3, emissions=0.0708)
# [SKIPPED] Facility: PORTLCN @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: PORTWF @ 2025-10-01 00:25:00+10:00 (power=68.2, emissions=0.0)
# [SKIPPED] Facility: PSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0015, emissions=0.0 | previous: power=0.0015, emissions=0.0)
# [SKIPPED] Facility: PTINA @ 2025-10-01 00:25:00+10:00 (current: power=3.33, emissions=0.0 | previous: power=3.33, emissions=0.0)
# [SKIPPED] Facility: QBYNB @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: QUARANTN @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: RANGEB @ 2025-10-01 00:25:00+10:00 (power=0.02, emissions=0.0)
# [UPDATED] Facility: REECE @ 2025-10-01 00:25:00+10:00 (power=117.5749, emissions=0.0)
# [UPDATED] Facility: REPULSE @ 2025-10-01 00:25:00+10:00 (power=33.2543, emissions=0.0)
# [SKIPPED] Facility: RESS @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: RIVNB @ 2025-10-01 00:25:00+10:00 (power=0.0928, emissions=0.0)
# [SKIPPED] Facility: ROMA @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: ROWALLAN @ 2025-10-01 00:25:00+10:00 (power=-0.0086, emissions=0.0)
# [SKIPPED] Facility: ROYALLA @ 2025-10-01 00:25:00+10:00 (current: power=0.001, emissions=0.0 | previous: power=0.001, emissions=0.0)
# [SKIPPED] Facility: RPCG @ 2025-10-01 00:25:00+10:00 (current: power=12.6, emissions=0.0487 | previous: power=12.6, emissions=0.0487)
# [SKIPPED] Facility: RRSF @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [SKIPPED] Facility: RUBICON @ 2025-10-01 00:25:00+10:00 (current: power=0.585, emissions=0.0 | previous: power=0.585, emissions=0.0)
# [SKIPPED] Facility: RUGBYR @ 2025-10-01 00:25:00+10:00 (current: power=0.0, emissions=0.0 | previous: power=0.0, emissions=0.0)
# [UPDATED] Facility: RYANCWF @ 2025-10-01 00:25:00+10:00 (power=77.07, emissions=0.0)
# [UPDATED] Facility: RYEPARK @ 2025-10-01 00:25:00+10:00 (power=186.4708, emissions=0.0)
# [UPDATED] Facility: SALTCRK @ 2025-10-01 00:25:00+10:00 (power=17.54, emissions=0.0)
#
#
# Stopping publisher...
# Disconnected from MQTT broker
